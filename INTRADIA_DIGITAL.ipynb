# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime, timedelta  # Asegúrate de importar timedelta

# %%
# Definir la ruta del archivo correctamente
archivo = r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Blip Historial de Atenciones\Consolidado BLIP.csv"
blip_ha = pd.read_csv(archivo, delimiter=';', encoding='latin1')  # Prueba con 'latin1'

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\wduran\AppData\Local\Temp\ipykernel_20052\3328381030.py:3: DtypeWarning: Columns (17,27,28,29,30,31,32,35,40,41,42,45,46,47,48,49,50,51,58,59,60,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,268,269,270,271,272,273,274,275,276,277,278,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309) have mixed types. Specify dtype option on import or set low_memory=False.
#   blip_ha = pd.read_csv(archivo, delimiter=';', encoding='latin1')  # Prueba con 'latin1'

# %%
blip_ha.sample(2)
# Out:
#         SequentialId                                   CustomerIdentity  \
# 121850       3766878  d6ba4baf-ecd4-4d98-bda5-7ce48b55baac@tunnel.ms...
# 102143       3786602  d0c5a369-6763-479e-901a-76a7a5235497@tunnel.ms...
#
#                                           AgentIdentity  \
# 121850   margioritangeli.munozrosado%40e.vtr.cl@blip.ai
# 102143  sebastiananthony.mattapaucar%40e.vtr.cl@blip.ai
#
#                         Status                 StorageDate  ExpirationDate  \
# 121850             Transferred  2026-02-04 22:22:01 -03:00             NaN
# 102143  ClosedClientInactivity  2026-02-08 21:33:03 -03:00             NaN
#
#                          CloseDate          Team  Closed             Tags  \
# 121850  2026-02-04 22:31:17 -03:00  Tecnico_Fijo    True              NaN
# 102143  2026-02-08 22:00:19 -03:00  Tecnico_Fijo    True  ["inactividad"]
#
#           QueueTime FirstResponseTime AverageResponseTime        CustomerName  \
# 121850  0d 00:01:59       0d 00:00:07             77.77 s         Karina Diaz
# 102143  0d 00:02:43       0d 00:00:15            171.14 s  Ester Vega araneda
#
#         CustomerEmail  CustomerGender  CustomerCity CustomerPhoneNumber  \
# 121850            NaN             NaN           NaN         56984903829
# 102143            NaN             NaN           NaN         56939637487
#
#                              AgentName                             AgentEmail  \
# 121850                 MARGIORIT MUÑOZ   margioritangeli.munozrosado@e.vtr.cl
# 102143  Sebastian Anthony Matta Paucar  sebastiananthony.mattapaucar@e.vtr.cl
#
#                           tunnel.owner             tunnel.originator      4  \
# 121850  routerclarovtrchile@msging.net  56984903829@wa.gw.msging.net  reset
# 102143  routerclarovtrchile@msging.net  56939637487@wa.gw.msging.net  reset
#
#          botOrigin               3 access_token     activity_id  appt_number  \
# 121850  18960652-4  Servicio Hogar      Mi Plan  Servicio Hogar          NaN
# 102143   6217659-8  Servicio Hogar      Mi Plan  Servicio Hogar  Inactividad
#
#        activeMessageFileName                                    1  \
# 121850                   NaN  Rep Dominicana 99 Casa Am, El Monte
# 102143                   NaN                                  NaN
#
#                                                    motivo  \
# 121850  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY3Rpd...
# 102143                                                NaN
#
#                                           2   direccion    problema  \
# 121850  Rep Dominicana 99 Casa Am, El Monte  25536034.0  1-3G8OVVVC
# 102143                                  NaN         NaN         NaN
#
#                                                afectacion adicional  \
# 121850  jfe/form/SV_2nsxPhTGlFpMkwS?Q_CHL=email&Q_DL=E...  Document
# 102143                                                NaN       NaN
#
#        campaignId campaignMessageTemplate         campaignOriginator  \
# 121850      reset                   reset   damaris.luna@clarovtr.cl
# 102143      reset                   reset  franco.vargas@clarovtr.cl
#
#                                    Campaign team priorityTag Menu Hogar  rut  \
# 121850  Rep Dominicana 99 Casa Am, El Monte  NaN         NaN        NaN  NaN
# 102143                                  NaN  NaN         NaN        NaN  NaN
#
#         Menu Principal number link actividad        nombreplanprincipal  \
# 121850             NaN    NaN  NaN       NaN  REP DOMINICANA 99 CASA AM
# 102143             NaN    NaN  NaN       NaN                        NaN
#
#                                                  svatotal  \
# 121850  Principales: Doble Pack Plus Fibra Hogar (Incl...
# 102143                                                NaN
#
#        databeneficiosincluidos  \
# 121850          Adicionales: -
# 102143                     NaN
#
#                                          preciopermanente      mes  \
# 121850  Stream TV Plus | Fibra Hogar | Plataformas str...  $41.990
# 102143                                                NaN      NaN
#
#        dctomensual montomensual totalproductoadicional cargomensual    fecha  \
# 121850          12      $11.000                $30.990           $0  $30.990
# 102143         NaN          NaN                    NaN          NaN      NaN
#
#        meta_ad_id meta_ad_headline meta_ad_type meta_ad_url headline body  \
# 121850        NaN              NaN          NaN         NaN      NaN  NaN
# 102143        NaN              NaN          NaN         NaN      NaN  NaN
#
#        source_type source_id source_url media_id Unnamed: 68 name variable1  \
# 121850         NaN       NaN        NaN      NaN         NaN  NaN       NaN
# 102143         NaN       NaN        NaN      NaN         NaN  NaN       NaN
#
#        rut_cliente 16-abr sept-13 manihual147.puertomontt SourceId SourceUrl  \
# 121850         NaN    NaN     NaN                     NaN      NaN       NaN
# 102143         NaN    NaN     NaN                     NaN      NaN       NaN
#
#        SourceTitle SourceType 1fb343d96c8c047208d6aed87c8044619  \
# 121850         NaN        NaN                               NaN
# 102143         NaN        NaN                               NaN
#
#        1617a24cae34446c8aa2c3db3f80b11ac 1bd610ac6a9454b06bd751b31126fb7da  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#         img nombre medios imagen 1ff453bf28b584cb0bed7e648acad79b9  \
# 121850  NaN    NaN    NaN    NaN                               NaN
# 102143  NaN    NaN    NaN    NaN                               NaN
#
#        18cdab2841ea34c338317d2b7f165244d 1aaa3799b8de743bb9e6246bfaf505b71  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#        1eb5000a368f6400a9c0520817feb1ad5 medio    5    6    7 montopago  \
# 121850                               NaN   NaN  NaN  NaN  NaN       NaN
# 102143                               NaN   NaN  NaN  NaN  NaN       NaN
#
#        numboleta fechacorte 11-oct 10:00-13:00horas  \
# 121850       NaN        NaN    NaN              NaN
# 102143       NaN        NaN    NaN              NaN
#
#        padrealbertohurtado385edif.iiidepto104.maipu  \
# 121850                                          NaN
# 102143                                          NaN
#
#        1095bdcd041c44c7aa01b093ccadaa80f 1c9989040ce8f4d5885017b6359923662  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#        12fe12be58c5a4c7fab5ab298cdb6fa95 178099630d82b44019a5f4bb8cdd61503  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#        15-abr bilbao30.cartagena 17-abr 13:00-16:00  \
# 121850    NaN                NaN    NaN         NaN
# 102143    NaN                NaN    NaN         NaN
#
#        cerroartilleria17357.sanbernardo tiporedproductotoa    0 monto numero  \
# 121850                              NaN                NaN  NaN   NaN    NaN
# 102143                              NaN                NaN  NaN   NaN    NaN
#
#        link97eeb2bbfdda44a6a2b3234620dedcde 16:00-19:00  \
# 121850                                  NaN         NaN
# 102143                                  NaN         NaN
#
#        alcpedroalarcon818depto1308.sanmiguel marca 10-jul 16:00-19:00horas  \
# 121850                                   NaN   NaN    NaN              NaN
# 102143                                   NaN   NaN    NaN              NaN
#
#        marianolatorre191.laligua activa 1f6a67d8399524d07a6aa0e3c2ef52b53  \
# 121850                       NaN    NaN                               NaN
# 102143                       NaN    NaN                               NaN
#
#        27-sept fidias880depto409.nunoa 183b751c05b344c9f93727013564688de  \
# 121850     NaN                     NaN                               NaN
# 102143     NaN                     NaN                               NaN
#
#        21-abr bernardoohiggins816depto39.concepcion  \
# 121850    NaN                                   NaN
# 102143    NaN                                   NaN
#
#        1034063fa9a0a461baff03b581168a1e8 1c2ec6328cafd4e5c872ba0e29932e348  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#        16673ece2806c417380c8161a1c75c379 16a08f94abb504971aea43c27e7714d7e  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#        17a7b513829c340e99e9f8809f4a4f5a5 1688a67309a284057b0791e1c735fd10e  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#        1c365d0d097c541de9bee621cf8834c60 182d8080dc24b46c4a97549d2e86b635f  \
# 121850                               NaN                               NaN
# 102143                               NaN                               NaN
#
#        1a386c37c444442d7bba3aa50ed1f4d8b NumeroSerie 28-jun 13:00-16:00horas  \
# 121850                               NaN         NaN    NaN              NaN
# 102143                               NaN         NaN    NaN              NaN
#
#        juanpablosegundo1811.curacav? 20-nov  \
# 121850                           NaN    NaN
# 102143                           NaN    NaN
#
#        avenidaloszapadores411edif.ponien-ddepto204.recoleta  \
# 121850                                                NaN
# 102143                                                NaN
#
#        leonidasperez2938edif.adepto1510.copiapo  \
# 121850                                      NaN
# 102143                                      NaN
#
#        1ee3aad4b42a1435b8064699c8016bd31 Unnamed: 144 Unnamed: 145  \
# 121850                               NaN          NaN          NaN
# 102143                               NaN          NaN          NaN
#
#        Unnamed: 146 Unnamed: 147 Unnamed: 148 Unnamed: 149 Unnamed: 150  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 151 Unnamed: 152 Unnamed: 153 Unnamed: 154 Unnamed: 155  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 156 Unnamed: 157 Unnamed: 158 Unnamed: 159 Unnamed: 160  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 161 Unnamed: 162 Unnamed: 163 Unnamed: 164 Unnamed: 165  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 166 Unnamed: 167 Unnamed: 168 Unnamed: 169 Unnamed: 170  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 171 Unnamed: 172 Unnamed: 173 Unnamed: 174 Unnamed: 175  \
# 121850           NaN          NaN          NaN          NaN          NaN
# 102143           NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 176 Unnamed: 177 Unnamed: 178 Unnamed: 179 Unnamed: 180  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 181 Unnamed: 182 Unnamed: 183 Unnamed: 184 Unnamed: 185  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 186 Unnamed: 187 Unnamed: 188 Unnamed: 189 Unnamed: 190  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 191 Unnamed: 192 Unnamed: 193 Unnamed: 194 Unnamed: 195  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 196 Unnamed: 197 Unnamed: 198 Unnamed: 199 Unnamed: 200  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 201 Unnamed: 202 Unnamed: 203 Unnamed: 204 Unnamed: 205  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 206 Unnamed: 207 Unnamed: 208 Unnamed: 209 Unnamed: 210  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 211 Unnamed: 212 Unnamed: 213 Unnamed: 214 Unnamed: 215  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 216 Unnamed: 217 Unnamed: 218 Unnamed: 219 Unnamed: 220  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 221 Unnamed: 222 Unnamed: 223 Unnamed: 224 Unnamed: 225  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 226 Unnamed: 227 Unnamed: 228 Unnamed: 229 Unnamed: 230  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 231 Unnamed: 232 Unnamed: 233 Unnamed: 234 Unnamed: 235  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 236 Unnamed: 237 Unnamed: 238 Unnamed: 239 Unnamed: 240  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 241 Unnamed: 242 Unnamed: 243 Unnamed: 244 Unnamed: 245  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249 Unnamed: 250  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 251 Unnamed: 252 Unnamed: 253 Unnamed: 254 Unnamed: 255  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 256 Unnamed: 257 Unnamed: 258 Unnamed: 259 Unnamed: 260  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 261 Unnamed: 262 Unnamed: 263 Unnamed: 264 Unnamed: 265  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 266  Unnamed: 267 Unnamed: 268 Unnamed: 269 Unnamed: 270  \
# 121850           NaN           NaN          NaN          NaN          NaN
# 102143           NaN           NaN          NaN          NaN          NaN
#
#        Unnamed: 271 Unnamed: 272 Unnamed: 273 Unnamed: 274 Unnamed: 275  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 276 Unnamed: 277 Unnamed: 278  Unnamed: 279 Unnamed: 280  \
# 121850          NaN          NaN          NaN           NaN          NaN
# 102143          NaN          NaN          NaN           NaN          NaN
#
#        Unnamed: 281 Unnamed: 282 Unnamed: 283 Unnamed: 284 Unnamed: 285  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 286 Unnamed: 287 Unnamed: 288 Unnamed: 289 Unnamed: 290  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 291 Unnamed: 292 Unnamed: 293 Unnamed: 294 Unnamed: 295  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 296 Unnamed: 297 Unnamed: 298 Unnamed: 299 Unnamed: 300  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 301 Unnamed: 302 Unnamed: 303 Unnamed: 304 Unnamed: 305  \
# 121850          NaN          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 306 Unnamed: 307 Unnamed: 308 Unnamed: 309
# 121850          NaN          NaN          NaN          NaN
# 102143          NaN          NaN          NaN          NaN

# %%
# Elimina duplicados basados en todas las columnas (puedes especificar columnas si lo prefieres)
blip_ha.drop_duplicates(inplace=True)

# %%
# --- 0) (Opcional) si vas a leer desde archivo, descomenta y ajusta la ruta ---
# blip_ha = pd.read_csv(r"C:\ruta\blip_ha.csv", encoding="utf-8", low_memory=False)

# --- 1) Diccionario con coincidencia exacta (claves en minúsculas) ---
reemplazos = {
    "u42796115%40konecta.com@blip.ai": "luisfelipe.escribanoormeno%@e.vtr.cl",
    "U43916386%40konecta.com@blip.ai": "jhonnyronald.gutierrezvillegas%@e.vtr.cl",
    "u48366048%40konecta.com@blip.ai": "blima.coaquispe%@e.vtr.cl",
    "U70564447%40konecta.com@blip.ai": "nelly.maurapaucar%@e.vtr.cl",
    "U73870648%40konecta.com@blip.ai": "sebastiananthony.mattapaucar%@e.vtr.cl",
    "U74641282%40konecta.com@blip.ai": "britany.fernandezpadilla%@e.vtr.cl",
    "U74963315%40konecta.com@blip.ai": "piero.quiroz%@e.vtr.cl",
    "U75628462%40konecta.com@blip.ai": "valery.gonzalesarango%@e.vtr.cl",
    "U76324259%40konecta.com@blip.ai": "cesar.jorgepusari%@e.vtr.cl",
    "U9953812%40konecta.com@blip.ai":  "carlos.gastelourreste%@e.vtr.cl"
}
# --- 3) Reemplazo exacto (sin regex) ---
blip_ha["AgentIdentity"] = blip_ha["AgentIdentity"].replace(reemplazos, regex=False)

# %%
# Forzar conversión individual respetando la zona horaria original
blip_ha['StorageDate'] = blip_ha['StorageDate'].apply(pd.to_datetime, errors='coerce')

# Extraer la fecha (solo parte de la fecha)
blip_ha['Fecha'] = blip_ha['StorageDate'].apply(lambda x: x.date() if pd.notnull(x) else pd.NaT)

# Extraer la hora (solo la parte de la hora)
blip_ha['HORA'] = blip_ha['StorageDate'].apply(lambda x: x.time() if pd.notnull(x) else pd.NaT)

# %%
blip_ha
# Out:
#         SequentialId                                   CustomerIdentity  \
# 0             268422  592f06db-1544-48e9-a91f-455b68299708@tunnel.ms...
# 1             268421  1a3a30fd-8c6b-4881-82de-48e97d3019f5@tunnel.ms...
# 2             268420  1deb71bd-4c96-40bc-bbe8-716e259ca9e3@tunnel.ms...
# 3             268419  b3236ea5-6ff4-4561-a2f2-f139cb61a0fe@tunnel.ms...
# 4             268418  a17567db-b3ce-410a-8063-4b784d231a4e@tunnel.ms...
# ...              ...                                                ...
# 144021       3744681  78a92e6e-02d3-4181-bfb1-60036fd2bc2d@tunnel.ms...
# 144022       3744680  c45ebb6e-6bcb-48b9-88d1-12a7f06038db@tunnel.ms...
# 144023       3744679  d90c7f12-4581-4bd6-9ed2-32955310fc93@tunnel.ms...
# 144024       3744678  a06204a3-2885-4582-9302-abe3ef93c2e9@tunnel.ms...
# 144025       3744677  78a92e6e-02d3-4181-bfb1-60036fd2bc2d@tunnel.ms...
#
#                                          AgentIdentity  \
# 0       jose.mechatovalqui%40ext.clarochile.cl@blip.ai
# 1       jose.mechatovalqui%40ext.clarochile.cl@blip.ai
# 2       jose.mechatovalqui%40ext.clarochile.cl@blip.ai
# 3       jose.mechatovalqui%40ext.clarochile.cl@blip.ai
# 4       jose.mechatovalqui%40ext.clarochile.cl@blip.ai
# ...                                                ...
# 144021     joaquinandre.parcoapayco%40e.vtr.cl@blip.ai
# 144022     joaquinandre.parcoapayco%40e.vtr.cl@blip.ai
# 144023   leonardojosue.arteagavives%40e.vtr.cl@blip.ai
# 144024   luisfelipe.escribanoormeno%40e.vtr.cl@blip.ai
# 144025             natalia.castanoa%40e.vtr.cl@blip.ai
#
#                         Status               StorageDate  ExpirationDate  \
# 0              ClosedAttendant 2026-02-22 23:47:15-03:00             NaN
# 1       ClosedClientInactivity 2026-02-22 23:43:50-03:00             NaN
# 2       ClosedClientInactivity 2026-02-22 23:40:43-03:00             NaN
# 3              ClosedAttendant 2026-02-22 23:36:12-03:00             NaN
# 4       ClosedClientInactivity 2026-02-22 23:35:24-03:00             NaN
# ...                        ...                       ...             ...
# 144021  ClosedClientInactivity 2026-02-01 00:00:22-03:00             NaN
# 144022             Transferred 2026-02-01 00:00:20-03:00             NaN
# 144023             Transferred 2026-02-01 00:00:15-03:00             NaN
# 144024  ClosedClientInactivity 2026-02-01 00:00:11-03:00             NaN
# 144025             Transferred 2026-02-01 00:00:09-03:00             NaN
#
#                          CloseDate                  Team  Closed  \
# 0       2026-02-22 23:54:47 -03:00       Comercial Hogar    True
# 1       2026-02-23 00:00:00 -03:00      Inicio_Hogar_Def    True
# 2       2026-02-22 23:48:00 -03:00         Tecnico Hogar    True
# 3       2026-02-22 23:39:24 -03:00         trans_d_movil    True
# 4       2026-02-23 00:05:00 -03:00  Inconv_Tec_Hogar_Def    True
# ...                            ...                   ...     ...
# 144021  2026-02-01 00:04:13 -03:00          Tecnico_Fijo    True
# 144022  2026-02-01 00:15:08 -03:00          Tecnico_Fijo    True
# 144023  2026-02-01 00:01:29 -03:00          Tecnico_Fijo    True
# 144024  2026-02-01 00:06:43 -03:00          Tecnico_Fijo    True
# 144025  2026-02-01 00:00:22 -03:00          Tecnico_Fijo    True
#
#                    Tags    QueueTime FirstResponseTime AverageResponseTime  \
# 0       ["FACTURACION"]  0d 00:00:45       0d 00:00:29             11.52 s
# 1       ["inactividad"]  0d 00:00:00       0d 00:00:11             56.57 s
# 2       ["inactividad"]  0d 00:00:00       0d 00:00:06                 NaN
# 3             ["HOGAR"]  0d 00:00:14       0d 00:00:20             25.18 s
# 4       ["inactividad"]  0d 00:00:00       0d 00:00:15             67.33 s
# ...                 ...          ...               ...                 ...
# 144021  ["inactividad"]  0d 00:00:56       0d 00:00:41                 NaN
# 144022              NaN  0d 00:00:59       0d 00:00:48                 NaN
# 144023              NaN  0d 00:00:02       0d 00:00:16                 NaN
# 144024  ["inactividad"]  0d 00:00:00       0d 00:00:20                 NaN
# 144025              NaN  0d 00:00:00               NaN                 NaN
#
#               CustomerName  CustomerEmail  CustomerGender  CustomerCity  \
# 0                 Fernando            NaN             NaN           NaN
# 1        Alejandra Retamal            NaN             NaN           NaN
# 2       alvarog verdugo nv            NaN             NaN           NaN
# 3                     Juan            NaN             NaN           NaN
# 4             Sindy Mesina            NaN             NaN           NaN
# ...                    ...            ...             ...           ...
# 144021              Estela            NaN             NaN           NaN
# 144022     Pablo Rodriguez            NaN             NaN           NaN
# 144023           Francisco            NaN             NaN           NaN
# 144024        El Bandolero            NaN             NaN           NaN
# 144025              Estela            NaN             NaN           NaN
#
#        CustomerPhoneNumber                      AgentName  \
# 0              56959688898                   Abel Mechato
# 1              56944117030                   Abel Mechato
# 2              56938743123                   Abel Mechato
# 3              56945525027                   Abel Mechato
# 4              56934380551                   Abel Mechato
# ...                    ...                            ...
# 144021         56979776763                  Joaquin Parco
# 144022         56934150919                  Joaquin Parco
# 144023         56984579296   LEONARDO JOSUE ARTEAGA VIVES
# 144024         56962036798   Luis Felipe Escribano Ormeño
# 144025         56979776763  AT_NATALIA CASTAÑO_57274093-5
#
#                                   AgentEmail                    tunnel.owner  \
# 0       jose.mechatovalqui@ext.clarochile.cl              clara28@msging.net
# 1       jose.mechatovalqui@ext.clarochile.cl              clara28@msging.net
# 2       jose.mechatovalqui@ext.clarochile.cl              clara28@msging.net
# 3       jose.mechatovalqui@ext.clarochile.cl              clara28@msging.net
# 4       jose.mechatovalqui@ext.clarochile.cl              clara28@msging.net
# ...                                      ...                             ...
# 144021     joaquinandre.parcoapayco@e.vtr.cl  routerclarovtrchile@msging.net
# 144022     joaquinandre.parcoapayco@e.vtr.cl  routerclarovtrchile@msging.net
# 144023   leonardojosue.arteagavives@e.vtr.cl  routerclarovtrchile@msging.net
# 144024   luisfelipe.escribanoormeno@e.vtr.cl  routerclarovtrchile@msging.net
# 144025             natalia.castanoa@e.vtr.cl  routerclarovtrchile@msging.net
#
#                    tunnel.originator         4         botOrigin  \
# 0       56959688898@wa.gw.msging.net  Fernando  CALLE LUMALLA 32
# 1       56944117030@wa.gw.msging.net       NaN               NaN
# 2       56938743123@wa.gw.msging.net       NaN               NaN
# 3       56945525027@wa.gw.msging.net       NaN               NaN
# 4       56934380551@wa.gw.msging.net       NaN               NaN
# ...                              ...       ...               ...
# 144021  56979776763@wa.gw.msging.net     reset         5583484-9
# 144022  56934150919@wa.gw.msging.net     reset        14086447-1
# 144023  56984579296@wa.gw.msging.net     reset               NaN
# 144024  56962036798@wa.gw.msging.net     reset        24394809-6
# 144025  56979776763@wa.gw.msging.net     reset         5583484-9
#
#                                                         3  \
# 0       Principales: Doble Pack Fibra 600 Hogar + TV P...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 144021                                                NaN
# 144022                                     Servicio Hogar
# 144023                                                NaN
# 144024                                     Servicio Hogar
# 144025                                                NaN
#
#                       access_token  \
# 0       Adicionales: 1 d-BOX Smart
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 144021                         NaN
# 144022                     Mi Plan
# 144023                         NaN
# 144024                         NaN
# 144025                         NaN
#
#                                               activity_id  appt_number  \
# 0       Fibra 600 | Stream TV Plus | Plataformas strea...        41990
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 144021                                     Servicio Hogar          NaN
# 144022                                     Servicio Hogar  Inactividad
# 144023                                     Servicio Hogar          NaN
# 144024                                     Servicio Hogar  Inactividad
# 144025                                     Servicio Hogar          NaN
#
#                   activeMessageFileName              1  \
# 0       Descuento por 12 meses: $18.000          23990
# 1                                   NaN            NaN
# 2                                   NaN            NaN
# 3                                   NaN            NaN
# 4                                   NaN            NaN
# ...                                 ...            ...
# 144021                              NaN            NaN
# 144022                              NaN  10:00 a 13:00
# 144023                              NaN            NaN
# 144024                              NaN  13:00 a 16:00
# 144025                              NaN            NaN
#
#                                                    motivo  \
# 0                                                    2800
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 144021                                                NaN
# 144022  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY3Rpd...
# 144023                                                NaN
# 144024  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY3Rpd...
# 144025                                                NaN
#
#                                             2                       direccion  \
# 0                                       26790  Calle Lumalla 32, Vina Del Mar
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN        Napoles 3437, Talcahuano
# 4                                         NaN                             NaN
# ...                                       ...                             ...
# 144021                                    NaN                             NaN
# 144022                          11:00 a 12:00                      26401750.0
# 144023                                    NaN                             NaN
# 144024  Moneda 720 Depto 211, Santiago Centro                      26181212.0
# 144025                                    NaN                             NaN
#
#                                                  problema  \
# 0       eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY3Rpd...
# 1                                                     NaN
# 2                                                     NaN
# 3       eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY3Rpd...
# 4                                                     NaN
# ...                                                   ...
# 144021                                                NaN
# 144022                                         1-3I9ESML8
# 144023                                                NaN
# 144024                                         1-3HUCMC4N
# 144025                                                NaN
#
#                               afectacion   adicional  campaignId  \
# 0         Calle Lumalla 32, Vina Del Mar  25808798.0  1-3GQT58DS
# 1                                    NaN         NaN         NaN
# 2                                    NaN         NaN         NaN
# 3               Napoles 3437, Talcahuano  24312887.0  1-3DZCGQ5V
# 4                                    NaN         NaN         NaN
# ...                                  ...         ...         ...
# 144021                               NaN         NaN         NaN
# 144022                             Pablo         NaN       reset
# 144023                               NaN         NaN         NaN
# 144024  https://i.imgur.com/ZRw3cCM.jpeg    Document       reset
# 144025                               NaN         NaN         NaN
#
#        campaignMessageTemplate  \
# 0                     Document
# 1                          NaN
# 2                          NaN
# 3                     Document
# 4                          NaN
# ...                        ...
# 144021                     NaN
# 144022                   reset
# 144023                     NaN
# 144024                   reset
# 144025                     NaN
#
#                                        campaignOriginator  \
# 0       jfe/form/SV_eJTfKh36Upal56C?Q_CHL=email&Q_DL=E...
# 1                                                     NaN
# 2                                                     NaN
# 3       jfe/form/SV_eJTfKh36Upal56C?Q_CHL=email&Q_DL=E...
# 4                                                     NaN
# ...                                                   ...
# 144021                                                NaN
# 144022                                                NaN
# 144023                                                NaN
# 144024                                                NaN
# 144025                                                NaN
#
#                                      Campaign        team priorityTag  \
# 0                    damaris.luna@clarovtr.cl  18034947-2        True
# 1                                         NaN         NaN         NaN
# 2                                         NaN  16129357-1        True
# 3                                         NaN  14404881-4        True
# 4                                         NaN         NaN         NaN
# ...                                       ...         ...         ...
# 144021                                    NaN         NaN         NaN
# 144022        Volcan Antuco 960, Puerto Montt         NaN         NaN
# 144023                                    NaN         NaN         NaN
# 144024  Moneda 720 Depto 211, Santiago Centro         NaN         NaN
# 144025                                    NaN         NaN         NaN
#
#                                   Menu Hogar  rut  Menu Principal  \
# 0                                      reset  NaN             NaN
# 1       2bbd1bca-0515-4010-836d-00d93ff9b074  NaN             NaN
# 2                                      reset  NaN             NaN
# 3       8053671b-4b2b-4529-823c-a202977e5337  NaN             NaN
# 4       59b90de1-6d7a-4bff-9619-daaab948422f  NaN             NaN
# ...                                      ...  ...             ...
# 144021                                   NaN  NaN             NaN
# 144022                                   NaN  NaN             NaN
# 144023                                   NaN  NaN             NaN
# 144024                                   NaN  NaN             NaN
# 144025                                   NaN  NaN             NaN
#
#                          number link actividad   nombreplanprincipal  \
# 0                         reset  NaN       NaN                   NaN
# 1       def_hogar_inicial_clara  NaN       NaN                   NaN
# 2                         reset  NaN       NaN                   NaN
# 3       def_hogar_inicial_clara  NaN       NaN                   NaN
# 4          inconv_tec_hogar_def  NaN       NaN                   NaN
# ...                         ...  ...       ...                   ...
# 144021                      NaN  NaN       NaN                   NaN
# 144022                      NaN  NaN       NaN                   NaN
# 144023                      NaN  NaN       NaN                   NaN
# 144024                      NaN  NaN       NaN  MONEDA 720 DEPTO 211
# 144025                      NaN  NaN       NaN                   NaN
#
#                                                  svatotal  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 144021                                                NaN
# 144022                                                NaN
# 144023                                                NaN
# 144024  Principales: Doble Pack Premium Fibra Hogar (I...
# 144025                                                NaN
#
#        databeneficiosincluidos  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 144021                     NaN
# 144022                     NaN
# 144023                     NaN
# 144024          Adicionales: -
# 144025                     NaN
#
#                                          preciopermanente  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 144021                                                NaN
# 144022                                                NaN
# 144023                                                NaN
# 144024  Stream TV Premium | Fibra Hogar | Plataformas ...
# 144025                                                NaN
#
#                             mes                         dctomensual  \
# 0                         reset                                 Ola
# 1       def_hogar_inicial_clara                    Iniciar Atención
# 2                         reset  {"botOrigin":"Finalizacion Clara"}
# 3       def_hogar_inicial_clara                    Iniciar Atención
# 4          inconv_tec_hogar_def                    Iniciar Atención
# ...                         ...                                 ...
# 144021                      NaN                                 NaN
# 144022                      NaN                                 NaN
# 144023                      NaN                                 NaN
# 144024                  $46.990                                  12
# 144025                      NaN                                 NaN
#
#                          montomensual totalproductoadicional  \
# 0                     comercial_hogar            Inactividad
# 1                    inicio_hogar_def            Inactividad
# 2                       tecnico_hogar                    NaN
# 3       Soporte Postventa Movil Clara            Inactividad
# 4                inconv_tec_hogar_def                    NaN
# ...                               ...                    ...
# 144021                            NaN                    NaN
# 144022                            NaN                    NaN
# 144023                            NaN                    NaN
# 144024                        $13.000                $33.990
# 144025                            NaN                    NaN
#
#                     cargomensual    fecha meta_ad_id meta_ad_headline  \
# 0                            NaN      NaN        NaN              NaN
# 1                            NaN      NaN        NaN              NaN
# 2                            NaN      NaN        NaN              NaN
# 3       Napoles 3437, Talcahuano      NaN        NaN              NaN
# 4                            NaN      NaN        NaN              NaN
# ...                          ...      ...        ...              ...
# 144021                       NaN      NaN        NaN              NaN
# 144022                       NaN      NaN        NaN              NaN
# 144023                       NaN      NaN        NaN              NaN
# 144024                        $0  $33.990        NaN              NaN
# 144025                       NaN      NaN        NaN              NaN
#
#        meta_ad_type meta_ad_url headline body source_type source_id  \
# 0               NaN         NaN      NaN  NaN         NaN       NaN
# 1               NaN         NaN      NaN  NaN         NaN       NaN
# 2               NaN         NaN      NaN  NaN         NaN       NaN
# 3               NaN         NaN      NaN  NaN         NaN       NaN
# 4               NaN         NaN      NaN  NaN         NaN       NaN
# ...             ...         ...      ...  ...         ...       ...
# 144021          NaN         NaN      NaN  NaN         NaN       NaN
# 144022          NaN         NaN      NaN  NaN         NaN       NaN
# 144023          NaN         NaN      NaN  NaN         NaN       NaN
# 144024          NaN         NaN      NaN  NaN         NaN       NaN
# 144025          NaN         NaN      NaN  NaN         NaN       NaN
#
#        source_url media_id Unnamed: 68 name variable1 rut_cliente 16-abr  \
# 0             NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 1             NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 2             NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 3             NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 4             NaN      NaN         NaN  NaN       NaN         NaN    NaN
# ...           ...      ...         ...  ...       ...         ...    ...
# 144021        NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 144022        NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 144023        NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 144024        NaN      NaN         NaN  NaN       NaN         NaN    NaN
# 144025        NaN      NaN         NaN  NaN       NaN         NaN    NaN
#
#        sept-13 manihual147.puertomontt SourceId SourceUrl SourceTitle  \
# 0          NaN                     NaN      NaN       NaN         NaN
# 1          NaN                     NaN      NaN       NaN         NaN
# 2          NaN                     NaN      NaN       NaN         NaN
# 3          NaN                     NaN      NaN       NaN         NaN
# 4          NaN                     NaN      NaN       NaN         NaN
# ...        ...                     ...      ...       ...         ...
# 144021     NaN                     NaN      NaN       NaN         NaN
# 144022     NaN                     NaN      NaN       NaN         NaN
# 144023     NaN                     NaN      NaN       NaN         NaN
# 144024     NaN                     NaN      NaN       NaN         NaN
# 144025     NaN                     NaN      NaN       NaN         NaN
#
#        SourceType 1fb343d96c8c047208d6aed87c8044619  \
# 0             NaN                               NaN
# 1             NaN                               NaN
# 2             NaN                               NaN
# 3             NaN                               NaN
# 4             NaN                               NaN
# ...           ...                               ...
# 144021        NaN                               NaN
# 144022        NaN                               NaN
# 144023        NaN                               NaN
# 144024        NaN                               NaN
# 144025        NaN                               NaN
#
#        1617a24cae34446c8aa2c3db3f80b11ac 1bd610ac6a9454b06bd751b31126fb7da  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#         img nombre medios imagen 1ff453bf28b584cb0bed7e648acad79b9  \
# 0       NaN    NaN    NaN    NaN                               NaN
# 1       NaN    NaN    NaN    NaN                               NaN
# 2       NaN    NaN    NaN    NaN                               NaN
# 3       NaN    NaN    NaN    NaN                               NaN
# 4       NaN    NaN    NaN    NaN                               NaN
# ...     ...    ...    ...    ...                               ...
# 144021  NaN    NaN    NaN    NaN                               NaN
# 144022  NaN    NaN    NaN    NaN                               NaN
# 144023  NaN    NaN    NaN    NaN                               NaN
# 144024  NaN    NaN    NaN    NaN                               NaN
# 144025  NaN    NaN    NaN    NaN                               NaN
#
#        18cdab2841ea34c338317d2b7f165244d 1aaa3799b8de743bb9e6246bfaf505b71  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#        1eb5000a368f6400a9c0520817feb1ad5 medio    5    6    7 montopago  \
# 0                                    NaN   NaN  NaN  NaN  NaN       NaN
# 1                                    NaN   NaN  NaN  NaN  NaN       NaN
# 2                                    NaN   NaN  NaN  NaN  NaN       NaN
# 3                                    NaN   NaN  NaN  NaN  NaN       NaN
# 4                                    NaN   NaN  NaN  NaN  NaN       NaN
# ...                                  ...   ...  ...  ...  ...       ...
# 144021                               NaN   NaN  NaN  NaN  NaN       NaN
# 144022                               NaN   NaN  NaN  NaN  NaN       NaN
# 144023                               NaN   NaN  NaN  NaN  NaN       NaN
# 144024                               NaN   NaN  NaN  NaN  NaN       NaN
# 144025                               NaN   NaN  NaN  NaN  NaN       NaN
#
#        numboleta fechacorte 11-oct 10:00-13:00horas  \
# 0            NaN        NaN    NaN              NaN
# 1            NaN        NaN    NaN              NaN
# 2            NaN        NaN    NaN              NaN
# 3            NaN        NaN    NaN              NaN
# 4            NaN        NaN    NaN              NaN
# ...          ...        ...    ...              ...
# 144021       NaN        NaN    NaN              NaN
# 144022       NaN        NaN    NaN              NaN
# 144023       NaN        NaN    NaN              NaN
# 144024       NaN        NaN    NaN              NaN
# 144025       NaN        NaN    NaN              NaN
#
#        padrealbertohurtado385edif.iiidepto104.maipu  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 144021                                          NaN
# 144022                                          NaN
# 144023                                          NaN
# 144024                                          NaN
# 144025                                          NaN
#
#        1095bdcd041c44c7aa01b093ccadaa80f 1c9989040ce8f4d5885017b6359923662  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#        12fe12be58c5a4c7fab5ab298cdb6fa95 178099630d82b44019a5f4bb8cdd61503  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#        15-abr bilbao30.cartagena 17-abr 13:00-16:00  \
# 0         NaN                NaN    NaN         NaN
# 1         NaN                NaN    NaN         NaN
# 2         NaN                NaN    NaN         NaN
# 3         NaN                NaN    NaN         NaN
# 4         NaN                NaN    NaN         NaN
# ...       ...                ...    ...         ...
# 144021    NaN                NaN    NaN         NaN
# 144022    NaN                NaN    NaN         NaN
# 144023    NaN                NaN    NaN         NaN
# 144024    NaN                NaN    NaN         NaN
# 144025    NaN                NaN    NaN         NaN
#
#        cerroartilleria17357.sanbernardo tiporedproductotoa    0 monto numero  \
# 0                                   NaN                NaN  NaN   NaN    NaN
# 1                                   NaN                NaN  NaN   NaN    NaN
# 2                                   NaN                NaN  NaN   NaN    NaN
# 3                                   NaN                NaN  NaN   NaN    NaN
# 4                                   NaN                NaN  NaN   NaN    NaN
# ...                                 ...                ...  ...   ...    ...
# 144021                              NaN                NaN  NaN   NaN    NaN
# 144022                              NaN                NaN  NaN   NaN    NaN
# 144023                              NaN                NaN  NaN   NaN    NaN
# 144024                              NaN                NaN  NaN   NaN    NaN
# 144025                              NaN                NaN  NaN   NaN    NaN
#
#        link97eeb2bbfdda44a6a2b3234620dedcde 16:00-19:00  \
# 0                                       NaN         NaN
# 1                                       NaN         NaN
# 2                                       NaN         NaN
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# ...                                     ...         ...
# 144021                                  NaN         NaN
# 144022                                  NaN         NaN
# 144023                                  NaN         NaN
# 144024                                  NaN         NaN
# 144025                                  NaN         NaN
#
#        alcpedroalarcon818depto1308.sanmiguel marca 10-jul 16:00-19:00horas  \
# 0                                        NaN   NaN    NaN              NaN
# 1                                        NaN   NaN    NaN              NaN
# 2                                        NaN   NaN    NaN              NaN
# 3                                        NaN   NaN    NaN              NaN
# 4                                        NaN   NaN    NaN              NaN
# ...                                      ...   ...    ...              ...
# 144021                                   NaN   NaN    NaN              NaN
# 144022                                   NaN   NaN    NaN              NaN
# 144023                                   NaN   NaN    NaN              NaN
# 144024                                   NaN   NaN    NaN              NaN
# 144025                                   NaN   NaN    NaN              NaN
#
#        marianolatorre191.laligua activa 1f6a67d8399524d07a6aa0e3c2ef52b53  \
# 0                            NaN    NaN                               NaN
# 1                            NaN    NaN                               NaN
# 2                            NaN    NaN                               NaN
# 3                            NaN    NaN                               NaN
# 4                            NaN    NaN                               NaN
# ...                          ...    ...                               ...
# 144021                       NaN    NaN                               NaN
# 144022                       NaN    NaN                               NaN
# 144023                       NaN    NaN                               NaN
# 144024                       NaN    NaN                               NaN
# 144025                       NaN    NaN                               NaN
#
#        27-sept fidias880depto409.nunoa 183b751c05b344c9f93727013564688de  \
# 0          NaN                     NaN                               NaN
# 1          NaN                     NaN                               NaN
# 2          NaN                     NaN                               NaN
# 3          NaN                     NaN                               NaN
# 4          NaN                     NaN                               NaN
# ...        ...                     ...                               ...
# 144021     NaN                     NaN                               NaN
# 144022     NaN                     NaN                               NaN
# 144023     NaN                     NaN                               NaN
# 144024     NaN                     NaN                               NaN
# 144025     NaN                     NaN                               NaN
#
#        21-abr bernardoohiggins816depto39.concepcion  \
# 0         NaN                                   NaN
# 1         NaN                                   NaN
# 2         NaN                                   NaN
# 3         NaN                                   NaN
# 4         NaN                                   NaN
# ...       ...                                   ...
# 144021    NaN                                   NaN
# 144022    NaN                                   NaN
# 144023    NaN                                   NaN
# 144024    NaN                                   NaN
# 144025    NaN                                   NaN
#
#        1034063fa9a0a461baff03b581168a1e8 1c2ec6328cafd4e5c872ba0e29932e348  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#        16673ece2806c417380c8161a1c75c379 16a08f94abb504971aea43c27e7714d7e  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#        17a7b513829c340e99e9f8809f4a4f5a5 1688a67309a284057b0791e1c735fd10e  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#        1c365d0d097c541de9bee621cf8834c60 182d8080dc24b46c4a97549d2e86b635f  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 144021                               NaN                               NaN
# 144022                               NaN                               NaN
# 144023                               NaN                               NaN
# 144024                               NaN                               NaN
# 144025                               NaN                               NaN
#
#        1a386c37c444442d7bba3aa50ed1f4d8b NumeroSerie 28-jun 13:00-16:00horas  \
# 0                                    NaN         NaN    NaN              NaN
# 1                                    NaN         NaN    NaN              NaN
# 2                                    NaN         NaN    NaN              NaN
# 3                                    NaN         NaN    NaN              NaN
# 4                                    NaN         NaN    NaN              NaN
# ...                                  ...         ...    ...              ...
# 144021                               NaN         NaN    NaN              NaN
# 144022                               NaN         NaN    NaN              NaN
# 144023                               NaN         NaN    NaN              NaN
# 144024                               NaN         NaN    NaN              NaN
# 144025                               NaN         NaN    NaN              NaN
#
#        juanpablosegundo1811.curacav? 20-nov  \
# 0                                NaN    NaN
# 1                                NaN    NaN
# 2                                NaN    NaN
# 3                                NaN    NaN
# 4                                NaN    NaN
# ...                              ...    ...
# 144021                           NaN    NaN
# 144022                           NaN    NaN
# 144023                           NaN    NaN
# 144024                           NaN    NaN
# 144025                           NaN    NaN
#
#        avenidaloszapadores411edif.ponien-ddepto204.recoleta  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 144021                                                NaN
# 144022                                                NaN
# 144023                                                NaN
# 144024                                                NaN
# 144025                                                NaN
#
#        leonidasperez2938edif.adepto1510.copiapo  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 144021                                      NaN
# 144022                                      NaN
# 144023                                      NaN
# 144024                                      NaN
# 144025                                      NaN
#
#        1ee3aad4b42a1435b8064699c8016bd31 Unnamed: 144 Unnamed: 145  \
# 0                                    NaN          NaN          NaN
# 1                                    NaN          NaN          NaN
# 2                                    NaN          NaN          NaN
# 3                                    NaN          NaN          NaN
# 4                                    NaN          NaN          NaN
# ...                                  ...          ...          ...
# 144021                               NaN          NaN          NaN
# 144022                               NaN          NaN          NaN
# 144023                               NaN          NaN          NaN
# 144024                               NaN          NaN          NaN
# 144025                               NaN          NaN          NaN
#
#        Unnamed: 146 Unnamed: 147 Unnamed: 148 Unnamed: 149 Unnamed: 150  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 151 Unnamed: 152 Unnamed: 153 Unnamed: 154 Unnamed: 155  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 156 Unnamed: 157 Unnamed: 158 Unnamed: 159 Unnamed: 160  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 161 Unnamed: 162 Unnamed: 163 Unnamed: 164 Unnamed: 165  \
# ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 226 Unnamed: 227 Unnamed: 228 Unnamed: 229 Unnamed: 230  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 231 Unnamed: 232 Unnamed: 233 Unnamed: 234 Unnamed: 235  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 236 Unnamed: 237 Unnamed: 238 Unnamed: 239 Unnamed: 240  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 241 Unnamed: 242 Unnamed: 243 Unnamed: 244 Unnamed: 245  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249 Unnamed: 250  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 251 Unnamed: 252 Unnamed: 253 Unnamed: 254 Unnamed: 255  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 256 Unnamed: 257 Unnamed: 258 Unnamed: 259 Unnamed: 260  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 261 Unnamed: 262 Unnamed: 263 Unnamed: 264 Unnamed: 265  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 266  Unnamed: 267 Unnamed: 268 Unnamed: 269 Unnamed: 270  \
# 0                NaN           NaN          NaN          NaN          NaN
# 1                NaN           NaN          NaN          NaN          NaN
# 2                NaN           NaN          NaN          NaN          NaN
# 3                NaN           NaN          NaN          NaN          NaN
# 4                NaN           NaN          NaN          NaN          NaN
# ...              ...           ...          ...          ...          ...
# 144021           NaN           NaN          NaN          NaN          NaN
# 144022           NaN           NaN          NaN          NaN          NaN
# 144023           NaN           NaN          NaN          NaN          NaN
# 144024           NaN           NaN          NaN          NaN          NaN
# 144025           NaN           NaN          NaN          NaN          NaN
#
#        Unnamed: 271 Unnamed: 272 Unnamed: 273 Unnamed: 274 Unnamed: 275  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 276 Unnamed: 277 Unnamed: 278  Unnamed: 279 Unnamed: 280  \
# 0               NaN          NaN          NaN           NaN          NaN
# 1               NaN          NaN          NaN           NaN          NaN
# 2               NaN          NaN          NaN           NaN          NaN
# 3               NaN          NaN          NaN           NaN          NaN
# 4               NaN          NaN          NaN           NaN          NaN
# ...             ...          ...          ...           ...          ...
# 144021          NaN          NaN          NaN           NaN          NaN
# 144022          NaN          NaN          NaN           NaN          NaN
# 144023          NaN          NaN          NaN           NaN          NaN
# 144024          NaN          NaN          NaN           NaN          NaN
# 144025          NaN          NaN          NaN           NaN          NaN
#
#        Unnamed: 281 Unnamed: 282 Unnamed: 283 Unnamed: 284 Unnamed: 285  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 286 Unnamed: 287 Unnamed: 288 Unnamed: 289 Unnamed: 290  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 291 Unnamed: 292 Unnamed: 293 Unnamed: 294 Unnamed: 295  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 296 Unnamed: 297 Unnamed: 298 Unnamed: 299 Unnamed: 300  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 301 Unnamed: 302 Unnamed: 303 Unnamed: 304 Unnamed: 305  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 144021          NaN          NaN          NaN          NaN          NaN
# 144022          NaN          NaN          NaN          NaN          NaN
# 144023          NaN          NaN          NaN          NaN          NaN
# 144024          NaN          NaN          NaN          NaN          NaN
# 144025          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 306 Unnamed: 307 Unnamed: 308 Unnamed: 309       Fecha  \
# 0               NaN          NaN          NaN          NaN  2026-02-22
# 1               NaN          NaN          NaN          NaN  2026-02-22
# 2               NaN          NaN          NaN          NaN  2026-02-22
# 3               NaN          NaN          NaN          NaN  2026-02-22
# 4               NaN          NaN          NaN          NaN  2026-02-22
# ...             ...          ...          ...          ...         ...
# 144021          NaN          NaN          NaN          NaN  2026-02-01
# 144022          NaN          NaN          NaN          NaN  2026-02-01
# 144023          NaN          NaN          NaN          NaN  2026-02-01
# 144024          NaN          NaN          NaN          NaN  2026-02-01
# 144025          NaN          NaN          NaN          NaN  2026-02-01
#
#             HORA
# 0       23:47:15
# 1       23:43:50
# 2       23:40:43
# 3       23:36:12
# 4       23:35:24
# ...          ...
# 144021  00:00:22
# 144022  00:00:20
# 144023  00:00:15
# 144024  00:00:11
# 144025  00:00:09
#
# [144026 rows x 312 columns]

# %%
# Eliminar los dos primeros caracteres de los campos
blip_ha['QueueTime'] = blip_ha['QueueTime'].str[3:]
blip_ha['FirstResponseTime'] = blip_ha['FirstResponseTime'].str[3:]

# %%
# Eliminar " s" si existe
blip_ha['AverageResponseTime'] = blip_ha['AverageResponseTime'].astype(str).str.replace(' s', '', regex=False)

# Quitar decimales si hay
blip_ha['AverageResponseTime'] = blip_ha['AverageResponseTime'].str.split('.').str[0]

# %%
# Crear el campo INTERVALO redondeando a 60 minutos
def calcular_intervalo(hora):
    nueva_hora = hora.replace(minute=0, second=0)  # Redondear al inicio de la hora
    return nueva_hora.strftime('%H:%M')

# Crear el campo INTERVALO
blip_ha['INTERVALO'] = blip_ha['HORA'].apply(calcular_intervalo)

# %%
blip_ha['Team'].value_counts()
# Out:
# Team
# Comercial_Fijo                 42378
# Tecnico_Fijo                   41995
# Contacto_telefonico             7380
# OP_WIMT                         6899
# Default                         5809
# Tecnico Hogar                   4839
# Comercial Hogar                 4405
# Cola_Triagge_Fijo               3682
# Masivos                         3227
# OP                              2792
# trans_d_movil                   2702
# Transf desde Movil              2244
# soporte_ott                     2196
# Postpago Tecnico                1868
# DIRECT_TRANSFER                 1719
# Instalación Pendiente           1555
# Abuse                           1149
# Inicio_Hogar_Def                1054
# Venta_OTT                        831
# SV_VTRFijo_Tecnico               784
# Red Neutra - Ventas Out          679
# masivo                           621
# RedNeutra_ventasout              610
# FallaMasivaDom                   576
# visita_tecnica                   478
# Inconv_Tec_Hogar_Def             315
# Soporte OTT                      265
# Cuenta Exacta Tecnico            184
# reagenda_cierre_redes            169
# venta_ott                        126
# red_neutra_out                   116
# Bloqueados Hogar                 111
# Intencion de desconexion          90
# Retencion Premium                 54
# Cl_Tecnica_Cierre_Asegurado       47
# OP_Def                            24
# trans_d_ventas                    19
# Bienvenida_OUT                    12
# Babysitting Hogar - Dia 14         4
# Transf desde Ventas                3
# contratar_ott                      3
# Contacto_fono_Konecta              2
# Cuenta Exacta Comercial            2
# Validacion_ventahogar_Claro        2
# Contacto Cross                     2
# clarobot                           1
# contratar_ott_vtr                  1
# Actualización de Datos             1
# Cambio_Dirección                   1
# Name: count, dtype: int64

# %%
# Lista de valores del campo 'Team' que deseas filtrar (en minúsculas para comparación insensible a mayúsculas/minúsculas)
teams_to_filter = [
    'Cambio_Dirección','Cambio_Direccion', 'Campaña_Fidelización','Campaña_Fidelizacion', 'Campaña_Reclamos', 
    'Comercial_Fijo', 'FTTH/IPTV', 'OP', 'Pla Solidario Vuelta Atrás','Pla Solidario Vuelta Atras', 'Transf desde Movil', 'Plan_Regularización_Redes', 'Masivos', 
    'Recontacto_Nocturno', 'Speed Trial Stock Management', 'Tecnico_Fijo', 'Default', 'DIRECT_TRANSFER', 'Comercial', 'Tecnico', 'DBOX SMART', 'Venta_OTT',
    'soporte_ott', 'Transf desde Ventas','Comercial_Def','Comercial_Fijo_Def','OP_Def', 'Tecnico_Def', 'Tecnico_Fijo_Def', 'IVR_Def',
    'Contacto Cross', 'consulta_boleta', 'CerradoMasivo','Cross_voz','red_neutra_out','RedNeutra_ventasout','ivr_def5','TecnicoFinix_Def','OTT_MAX',
'Cuenta Exacta Comercial','Cuenta Exacta Tecnico','Default','Gestión','Instalación Pendiente','Postpago Comercial','Postpago Tecnico','trans_d_ventas','trans_d_movil','clarobot','masivo','visita_tecnica',
    'Comercial Hogar','Tecnico Hogar','Retencion Premium','Abuse','Bienvenida_OUT','masivo','Transferencia directa','Contacto_fono_Konecta','Botón Rojo Comercial','Babysitting Hogar - Dia 3','Babysitting Hogar - Dia 14',
    'Contacto_telefonico','Contacto Videollamada en línea','IVR_5','IVR_Def','Prepago Tecnico','Trasnferencia directa','OP_WIMT','masivos','soporte_ott OTT','Venta_OTT','OP_Def','SV_VTRFijo_Tecnico','Inconv_Tec_Hogar_Def'
]


# Filtrar la base 'blip_ha' usando .isin() para la columna 'Team'
f_blip_ha = blip_ha[blip_ha['Team'].isin(teams_to_filter)]

# %%
f_blip_ha['Team'].value_counts()
# Out:
# Team
# Comercial_Fijo                42378
# Tecnico_Fijo                  41995
# Contacto_telefonico            7380
# OP_WIMT                        6899
# Default                        5809
# Tecnico Hogar                  4839
# Comercial Hogar                4405
# Masivos                        3227
# OP                             2792
# trans_d_movil                  2702
# Transf desde Movil             2244
# soporte_ott                    2196
# Postpago Tecnico               1868
# DIRECT_TRANSFER                1719
# Instalación Pendiente          1555
# Abuse                          1149
# Venta_OTT                       831
# SV_VTRFijo_Tecnico              784
# masivo                          621
# RedNeutra_ventasout             610
# visita_tecnica                  478
# Inconv_Tec_Hogar_Def            315
# Cuenta Exacta Tecnico           184
# red_neutra_out                  116
# Retencion Premium                54
# OP_Def                           24
# trans_d_ventas                   19
# Bienvenida_OUT                   12
# Babysitting Hogar - Dia 14        4
# Transf desde Ventas               3
# Cuenta Exacta Comercial           2
# Contacto_fono_Konecta             2
# Contacto Cross                    2
# clarobot                          1
# Cambio_Dirección                  1
# Name: count, dtype: int64

# %%
f_blip_ha.sample(1)
# Out:
#         SequentialId                                   CustomerIdentity  \
# 128387       3760332  aaf1b43d-a5d1-424f-9ee0-e133333b071c@tunnel.ms...
#
#                                   AgentIdentity       Status  \
# 128387  angely.mejiacastillo%40e.vtr.cl@blip.ai  Transferred
#
#                      StorageDate  ExpirationDate                   CloseDate  \
# 128387 2026-02-03 20:36:47-03:00             NaN  2026-02-03 20:40:01 -03:00
#
#            Team  Closed Tags QueueTime FirstResponseTime AverageResponseTime  \
# 128387  Masivos    True  NaN  00:00:00          00:00:17                 123
#
#        CustomerName  CustomerEmail  CustomerGender  CustomerCity  \
# 128387         Hola            NaN             NaN           NaN
#
#        CustomerPhoneNumber     AgentName                     AgentEmail  \
# 128387         56951177325  Angely Mejia  angely.mejiacastillo@e.vtr.cl
#
#                           tunnel.owner             tunnel.originator      4  \
# 128387  routerclarovtrchile@msging.net  56951177325@wa.gw.msging.net  reset
#
#          botOrigin               3 access_token     activity_id  appt_number  \
# 128387  16318314-5  Servicio Hogar      Mi Plan  Servicio Hogar  Inactividad
#
#        activeMessageFileName              1  \
# 128387                   NaN  13:00 a 16:00
#
#                                                    motivo  \
# 128387  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY3Rpd...
#
#                                             2   direccion    problema  \
# 128387  Laguna Del Desierto 582, Puerto Montt  26217628.0  1-3HXRCRDX
#
#                               afectacion adicional campaignId  \
# 128387  https://i.imgur.com/XhrREcP.jpeg  Document      reset
#
#        campaignMessageTemplate campaignOriginator  \
# 128387                   reset                NaN
#
#                                      Campaign team priorityTag Menu Hogar  \
# 128387  Laguna Del Desierto 582, Puerto Montt  NaN         NaN        NaN
#
#         rut  Menu Principal number link actividad      nombreplanprincipal  \
# 128387  NaN             NaN    NaN  NaN       NaN  LAGUNA DEL DESIERTO 582
#
#                                                  svatotal  \
# 128387  Principales: Doble Pack Fibra Hogar + Stream T...
#
#        databeneficiosincluidos  \
# 128387          Adicionales: -
#
#                                          preciopermanente      mes  \
# 128387  Stream TV Inicia| Fibra Hogar | Plataformas st...  $41.990
#
#        dctomensual montomensual totalproductoadicional cargomensual    fecha  \
# 128387          12      $16.000                $25.990           $0  $25.990
#
#        meta_ad_id meta_ad_headline meta_ad_type meta_ad_url headline body  \
# 128387        NaN              NaN          NaN         NaN      NaN  NaN
#
#        source_type source_id source_url media_id Unnamed: 68 name variable1  \
# 128387         NaN       NaN        NaN      NaN         NaN  NaN       NaN
#
#        rut_cliente 16-abr sept-13 manihual147.puertomontt SourceId SourceUrl  \
# 128387         NaN    NaN     NaN                     NaN      NaN       NaN
#
#        SourceTitle SourceType 1fb343d96c8c047208d6aed87c8044619  \
# 128387         NaN        NaN                               NaN
#
#        1617a24cae34446c8aa2c3db3f80b11ac 1bd610ac6a9454b06bd751b31126fb7da  \
# 128387                               NaN                               NaN
#
#         img nombre medios imagen 1ff453bf28b584cb0bed7e648acad79b9  \
# 128387  NaN    NaN    NaN    NaN                               NaN
#
#        18cdab2841ea34c338317d2b7f165244d 1aaa3799b8de743bb9e6246bfaf505b71  \
# 128387                               NaN                               NaN
#
#        1eb5000a368f6400a9c0520817feb1ad5 medio    5    6    7 montopago  \
# 128387                               NaN   NaN  NaN  NaN  NaN       NaN
#
#        numboleta fechacorte 11-oct 10:00-13:00horas  \
# 128387       NaN        NaN    NaN              NaN
#
#        padrealbertohurtado385edif.iiidepto104.maipu  \
# 128387                                          NaN
#
#        1095bdcd041c44c7aa01b093ccadaa80f 1c9989040ce8f4d5885017b6359923662  \
# 128387                               NaN                               NaN
#
#        12fe12be58c5a4c7fab5ab298cdb6fa95 178099630d82b44019a5f4bb8cdd61503  \
# 128387                               NaN                               NaN
#
#        15-abr bilbao30.cartagena 17-abr 13:00-16:00  \
# 128387    NaN                NaN    NaN         NaN
#
#        cerroartilleria17357.sanbernardo tiporedproductotoa    0 monto numero  \
# 128387                              NaN                NaN  NaN   NaN    NaN
#
#        link97eeb2bbfdda44a6a2b3234620dedcde 16:00-19:00  \
# 128387                                  NaN         NaN
#
#        alcpedroalarcon818depto1308.sanmiguel marca 10-jul 16:00-19:00horas  \
# 128387                                   NaN   NaN    NaN              NaN
#
#        marianolatorre191.laligua activa 1f6a67d8399524d07a6aa0e3c2ef52b53  \
# 128387                       NaN    NaN                               NaN
#
#        27-sept fidias880depto409.nunoa 183b751c05b344c9f93727013564688de  \
# 128387     NaN                     NaN                               NaN
#
#        21-abr bernardoohiggins816depto39.concepcion  \
# 128387    NaN                                   NaN
#
#        1034063fa9a0a461baff03b581168a1e8 1c2ec6328cafd4e5c872ba0e29932e348  \
# 128387                               NaN                               NaN
#
#        16673ece2806c417380c8161a1c75c379 16a08f94abb504971aea43c27e7714d7e  \
# 128387                               NaN                               NaN
#
#        17a7b513829c340e99e9f8809f4a4f5a5 1688a67309a284057b0791e1c735fd10e  \
# 128387                               NaN                               NaN
#
#        1c365d0d097c541de9bee621cf8834c60 182d8080dc24b46c4a97549d2e86b635f  \
# 128387                               NaN                               NaN
#
#        1a386c37c444442d7bba3aa50ed1f4d8b NumeroSerie 28-jun 13:00-16:00horas  \
# 128387                               NaN         NaN    NaN              NaN
#
#        juanpablosegundo1811.curacav? 20-nov  \
# 128387                           NaN    NaN
#
#        avenidaloszapadores411edif.ponien-ddepto204.recoleta  \
# 128387                                                NaN
#
#        leonidasperez2938edif.adepto1510.copiapo  \
# 128387                                      NaN
#
#        1ee3aad4b42a1435b8064699c8016bd31 Unnamed: 144 Unnamed: 145  \
# 128387                               NaN          NaN          NaN
#
#        Unnamed: 146 Unnamed: 147 Unnamed: 148 Unnamed: 149 Unnamed: 150  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 151 Unnamed: 152 Unnamed: 153 Unnamed: 154 Unnamed: 155  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 156 Unnamed: 157 Unnamed: 158 Unnamed: 159 Unnamed: 160  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 161 Unnamed: 162 Unnamed: 163 Unnamed: 164 Unnamed: 165  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 166 Unnamed: 167 Unnamed: 168 Unnamed: 169 Unnamed: 170  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 171 Unnamed: 172 Unnamed: 173 Unnamed: 174 Unnamed: 175  \
# 128387           NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 176 Unnamed: 177 Unnamed: 178 Unnamed: 179 Unnamed: 180  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 181 Unnamed: 182 Unnamed: 183 Unnamed: 184 Unnamed: 185  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 186 Unnamed: 187 Unnamed: 188 Unnamed: 189 Unnamed: 190  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 191 Unnamed: 192 Unnamed: 193 Unnamed: 194 Unnamed: 195  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 196 Unnamed: 197 Unnamed: 198 Unnamed: 199 Unnamed: 200  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 201 Unnamed: 202 Unnamed: 203 Unnamed: 204 Unnamed: 205  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 206 Unnamed: 207 Unnamed: 208 Unnamed: 209 Unnamed: 210  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 211 Unnamed: 212 Unnamed: 213 Unnamed: 214 Unnamed: 215  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 216 Unnamed: 217 Unnamed: 218 Unnamed: 219 Unnamed: 220  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 221 Unnamed: 222 Unnamed: 223 Unnamed: 224 Unnamed: 225  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 226 Unnamed: 227 Unnamed: 228 Unnamed: 229 Unnamed: 230  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 231 Unnamed: 232 Unnamed: 233 Unnamed: 234 Unnamed: 235  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 236 Unnamed: 237 Unnamed: 238 Unnamed: 239 Unnamed: 240  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 241 Unnamed: 242 Unnamed: 243 Unnamed: 244 Unnamed: 245  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249 Unnamed: 250  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 251 Unnamed: 252 Unnamed: 253 Unnamed: 254 Unnamed: 255  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 256 Unnamed: 257 Unnamed: 258 Unnamed: 259 Unnamed: 260  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 261 Unnamed: 262 Unnamed: 263 Unnamed: 264 Unnamed: 265  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 266  Unnamed: 267 Unnamed: 268 Unnamed: 269 Unnamed: 270  \
# 128387           NaN           NaN          NaN          NaN          NaN
#
#        Unnamed: 271 Unnamed: 272 Unnamed: 273 Unnamed: 274 Unnamed: 275  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 276 Unnamed: 277 Unnamed: 278  Unnamed: 279 Unnamed: 280  \
# 128387          NaN          NaN          NaN           NaN          NaN
#
#        Unnamed: 281 Unnamed: 282 Unnamed: 283 Unnamed: 284 Unnamed: 285  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 286 Unnamed: 287 Unnamed: 288 Unnamed: 289 Unnamed: 290  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 291 Unnamed: 292 Unnamed: 293 Unnamed: 294 Unnamed: 295  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 296 Unnamed: 297 Unnamed: 298 Unnamed: 299 Unnamed: 300  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 301 Unnamed: 302 Unnamed: 303 Unnamed: 304 Unnamed: 305  \
# 128387          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 306 Unnamed: 307 Unnamed: 308 Unnamed: 309       Fecha  \
# 128387          NaN          NaN          NaN          NaN  2026-02-03
#
#             HORA INTERVALO
# 128387  20:36:47     20:00

# %%
# Agregar el campo NEUTRA con valor 1 si 'Team' es igual a 'red_neutra_out', y 0 en caso contrario
f_blip_ha['NEUTRA'] = f_blip_ha['Team'].apply(lambda x: 1 if x == 'red_neutra_out' else 0)
# Out:
# C:\Users\wduran\AppData\Local\Temp\ipykernel_20052\104272697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_blip_ha['NEUTRA'] = f_blip_ha['Team'].apply(lambda x: 1 if x == 'red_neutra_out' else 0)

# %%
# Eliminar columnas que contienen "Unnamed" en su nombre
f_blip_ha = f_blip_ha.loc[:, ~f_blip_ha.columns.str.contains('^Unnamed')]
# Eliminar columnas que contienen un punto (.) en su nombre, excepto 'Team.1'
f_blip_ha = f_blip_ha.loc[:, ~f_blip_ha.columns.str.contains(r'\.') | f_blip_ha.columns.str.contains('Team.1')]
# Eliminar columnas que contienen la palabra "link" en su nombre
f_blip_ha = f_blip_ha.loc[:, ~f_blip_ha.columns.str.contains('link', case=False, na=False)]

# %%
# Definir una función para validar el formato del RUT
def validar_rut(rut):
    patron = r"^\d{7,8}-[0-9Kk]$"  # Ejemplo: 15478996-0 o 15478996-K
    return bool(re.match(patron, str(rut)))

# Revisar cada fila y buscar RUT en otras columnas
columnas_a_revisar = [col for col in f_blip_ha.columns if col != "rut"]  # Todas las columnas excepto "RUT"

for index, row in f_blip_ha.iterrows():
    # Validar si el campo RUT es válido
    if not validar_rut(row["rut"]):
        # Buscar un RUT válido en otras columnas
        for col in columnas_a_revisar:
            if validar_rut(row[col]):
                f_blip_ha.at[index, "rut"] = row[col]  # Mover el RUT al campo correcto
                break  # Dejar de buscar una vez encontrado
# Out:
# C:\Users\wduran\AppData\Local\Temp\ipykernel_20052\692789625.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18034947-2' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   f_blip_ha.at[index, "rut"] = row[col]  # Mover el RUT al campo correcto

# %%
f_blip_ha

# %%
# Convertir todos los valores de la columna 'Cola' a minúsculas
f_blip_ha['Team'] = f_blip_ha['Team'].str.lower()

# %%
def calcular_semana_lunes(fecha):
    if pd.isnull(fecha):
        return None
    # Primer día del mes
    primer_dia_mes = fecha.replace(day=1)
    # Determinar el lunes de la primera semana del mes
    primer_lunes = primer_dia_mes + timedelta(days=(7 - primer_dia_mes.weekday()) % 7)
    if primer_lunes.month != fecha.month:
        primer_lunes -= timedelta(days=7)  # Ajustar si el primer lunes cae en el mes siguiente
    # Calcular el número de semana
    delta = (fecha - primer_lunes).days
    return delta // 7 + 1 if delta >= 0 else 1

f_blip_ha['Semana'] = f_blip_ha['Fecha'].apply(calcular_semana_lunes)

# %%
def agregar_campo_def_ibr(f_blip_ha):
    """
    Agrega un campo llamado 'Def_IBR' a la base de datos f_blip_ha.
    """
    # Asegurarse de que no haya valores nulos para evitar errores de búsqueda
    f_blip_ha.fillna("", inplace=True)
    
    # Función para verificar la condición
    def verificar_def_ibr(row):
        if "ivr_def5" in str(row.get('Campaign', '')).lower():
            return 1
        elif any("ivr_def5" in str(value).lower() for value in row):
            return 1
        else:
            return 0
    
    # Crear el nuevo campo aplicando la función a cada fila
    f_blip_ha['Def_IBR'] = f_blip_ha.apply(verificar_def_ibr, axis=1)
agregar_campo_def_ibr(f_blip_ha)  # Modifica directamente f_blip_ha

# %%
f_blip_ha

# %%
f_blip_ha['Fecha'] = f_blip_ha['Fecha'].astype(str)

# Crear el campo 'Llave' concatenando 'Telefono Cliente' y 'Fecha'
f_blip_ha['Llave'] = f_blip_ha['CustomerPhoneNumber'].astype(str) + "_" + f_blip_ha['Fecha']

# %%
f_blip_ha

# %%
## Lista de valores permitidos
valores_outbound = {
    "confirmacion_agenda", "encuesta_satisfaccion_fase2_v3", "contacto_cros",
    "Cancelar Visita", "masivocerrado2", "Reagendar Visita", "fallvtr_v1",
    "contacto_cross_voz_", "cierre_asegurado_redes", "red_solicitud_instalacion_fibra_v5",
    "masivocerrado_v2", "post_visita_tecnica", "superclasicolovsu", "Confirmacion Agenda",
    "activamax_", "variables_vtr", "iptv_mensaje2", "promomax_", "post_visita_tecnica_v2",
    "fuera_de_horario", "template_mega_940_2", "encuesta_satisfaccion_fase2", "no_contesta",
    "encuesta_satisfaccion_post_servicio", "agendamiento_migra", "fallavtr",
    "validacion_identidad_no_portabilidad_vtr", "red_solicitud_instalacion_fibra_",
    "template_mega_500", "validacion_identidad_no_portabilidad_vtr_dev",
    "validacion_identidad_portabilidad_vtr"
}

# Función para determinar el valor de Flag_Outbound
def flag_outbound(row):
    # Verificar si campaignMessageTemplate está en la lista
    if row['campaignMessageTemplate'] in valores_outbound:
        return 1
    
    # Si no está en campaignMessageTemplate, revisar todas las columnas
    for value in row:
        if isinstance(value, str) and value in valores_outbound:
            return 1
    
    # Si no hay coincidencias, devolver 0
    return 0

# Aplicar la función a todas las filas del DataFrame f_blip_ha
f_blip_ha['Flag_Outbound'] = f_blip_ha.apply(flag_outbound, axis=1)

# %%
f_blip_ha['Flag_Outbound'].value_counts()

# %%
# Define the file path
archivo = r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Dotaciones\VTR\Dotacion_CLAROVTR_20260130.xlsx"
# Read the specific sheet named 'Dotacion' from the Excel file
dotacion = pd.read_excel(archivo, sheet_name='BASE VF')  # Specify the sheet name

# %% [markdown]
# # Convertimos los campos necesarios a minúsculas para comparar
# dotacion_filtrada = dotacion[
#     (dotacion['EMPRESA_PAIS'].str.lower() == 'konecta peru') &
#     (dotacion['PLATAFORMA'].str.lower().isin(['0 wsp. oopp', '0 wsp postventa']))
# ]

# %% [markdown]
# # Crear la nueva columna MAIL que extrae la parte izquierda del arroba
# dotacion_filtrada['MAIL'] = dotacion_filtrada['CORREO_ELECTRONICO'].str.split('@').str[0]

# %%
# Crear la nueva columna MAIL que extrae la parte izquierda del arroba
f_blip_ha['MAIL'] = f_blip_ha['AgentIdentity'].str.split('%').str[0]

# %%
f_blip_ha.sample(1)

# %%
# Creamos versiones en minúscula del campo MAIL para el join
f_blip_ha['MAIL_lower'] = f_blip_ha['MAIL'].str.lower()
dotacion['MAIL_lower'] = dotacion['MAIL'].str.lower()

f_blip_ha_merge = f_blip_ha.merge(
    dotacion[['MAIL_lower', 'EMPRESA_PAIS']].drop_duplicates(),
    on='MAIL_lower',
    how='left',
    indicator=True
)

# Creamos la bandera según si hubo match o no
#f_blip_ha_merge['Flag_Dotacion_Konecta'] = f_blip_ha_merge['_merge'].apply(lambda x: 1 if x == 'both' else 0)

# Eliminamos columnas auxiliares si no las necesitas
f_blip_ha_merge = f_blip_ha_merge.drop(columns=['MAIL_lower', '_merge'])

# %%
f_blip_ha_merge

# %%
# Elimina duplicados basados en todas las columnas (puedes especificar columnas si lo prefieres)
f_blip_ha_merge.drop_duplicates(inplace=True)

# %%
# Ruta al archivo
ruta_archivo = r"C:\Users\wduran\Downloads\Deflexiones_20251026.xlsx"

# Leer el archivo Excel (por defecto lee la primera hoja)
defle_meta = pd.read_excel(ruta_archivo)

# %%
defle_meta.sample(1)

# %%
defle_meta['Llave'] = defle_meta['ANI'].astype(str) + "_" + defle_meta['startdatetime'].astype(str)

# %%
# Paso 2: Seleccionar sólo las columnas necesarias de defle_meta
defle_meta_reducida = defle_meta[['Llave', 'Rama']].copy()

# Paso 3: Realizar el merge
f_blip_ha_merge = f_blip_ha_merge.merge(defle_meta_reducida, on='Llave', how='left')

# Paso 4: Crear el campo Defle_meta (1 si encontró coincidencia, 0 si no)
f_blip_ha_merge['Defle_meta'] = f_blip_ha_merge['Rama'].notna().astype(int)

# %%
f_blip_ha_merge['SequentialId'] = f_blip_ha_merge['SequentialId'].astype(int)

# %%
f_blip_ha_merge

# %%
f_blip_ha_merge['SequentialId'] = (
    pd.to_numeric(f_blip_ha_merge['SequentialId'], errors='coerce')  # → float
      .astype('Int64')                                              # → entero sin decimales
)

# 2) Eliminar duplicados por SequentialId (conserva la primera aparición)
f_blip_ha_merge = (
    f_blip_ha_merge
      .drop_duplicates(subset='SequentialId', keep='first')
      .reset_index(drop=True)
)

# %%
f_blip_ha_merge

# %%
df_2 = f_blip_ha_merge                      
df_1 = pd.read_csv(
    r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Blip Power Bi Base\f_blip_ha.csv",
    sep=",",               # cambia a ";" si el archivo está separado por punto y coma
    encoding="utf-8"       # o "latin1" si encuentras problemas de acentos
)

# %%
df_1

# %%
# 2) Concatenación
df_consolidado = pd.concat([df_1, df_2], ignore_index=True)

# %%
df_consolidado["StorageDate"] = df_consolidado["StorageDate"].astype(str).str.slice(0,19)

# %%
# Reemplazar valores infinitos por NaN
df_consolidado['AverageResponseTime'] = pd.to_numeric(df_consolidado['AverageResponseTime'], errors='coerce')

# Reemplazar NaN por 0 (o el valor que desees)
df_consolidado['AverageResponseTime'] = df_consolidado['AverageResponseTime'].replace([np.inf, -np.inf], np.nan).fillna(0)

# Convertir finalmente a int
df_consolidado['AverageResponseTime'] = df_consolidado['AverageResponseTime'].astype(int)

# %%
df_consolidado.sample(1)

# %%
df_consolidado = df_consolidado[df_consolidado.columns[~df_consolidado.columns.str.match(r'^\d')]]

# %%
df_consolidado = df_consolidado.drop_duplicates(subset=['SequentialId'], keep='first')

# %%
df_consolidado['Team'].value_counts()

# %% [markdown]
# # guarda el dataframe

# %%
# Guarda el DataFrame consolidado como CSV en la ubicación deseada
df_consolidado.to_csv(
    r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Blip Power Bi Base\f_blip_ha.csv",
    index=False,
    encoding="utf-8"
)

# %% [markdown]
# # DUPLICADO DE SEGURIDAD

# %%
df_consolidado

# %%
# Guarda el DataFrame consolidado como CSV en la ubicación deseada
df_consolidado.to_csv(
    r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Blip Power Bi Base\f_blip_ha_DUPLICADO_SEGURIDAD.csv",
    index=False,
    encoding="utf-8"
)

# %% [markdown]
# # DE SER NECESARIO ELIMINA DATA DEL MES

# %%
# 1) Asegúrate de que la columna Fecha sea tipo datetime
df_consolidado['Fecha'] = pd.to_datetime(df_consolidado['Fecha'], errors='coerce')

# 2) Filtra para eliminar registros de julio 2025 (mes = 7)
filtro = ~((df_consolidado['Fecha'].dt.year == 2026) & 
           (df_consolidado['Fecha'].dt.month == 2))

# 3) Aplica el filtro
df_consolidado = df_consolidado[filtro].reset_index(drop=True)

# %% [markdown]
# # Revisa

# %%
# 1) Garantiza que 'Fecha' sea datetime (si no lo hiciste antes)
df_consolidado['Fecha'] = pd.to_datetime(df_consolidado['Fecha'], errors='coerce')

# 2a) —‑ JULIO DE CUALQUIER AÑO
df_enero_2025 = df_consolidado[df_consolidado['Fecha'].dt.month == 2]

# 2b) —‑ SOLO JULIO 2025
df_enero_2025 = df_consolidado[
    (df_consolidado['Fecha'].dt.year == 2026) &
    (df_consolidado['Fecha'].dt.month == 2)]

# %%
df_enero_2025
# Out:
# Empty DataFrame
# Columns: [SequentialId, CustomerIdentity, AgentIdentity, Status, StorageDate, ExpirationDate, CloseDate, Team, Closed, Tags, QueueTime, FirstResponseTime, AverageResponseTime, CustomerName, CustomerEmail, CustomerGender, CustomerCity, CustomerPhoneNumber, AgentName, AgentEmail, campaignOriginator, botOrigin, campaignMessageTemplate, campaignId, Menu Hogar, priorityTag, Campaign, Menu Principal, team, rut, activeMessageFileName, actividad, activa, headline, body, source_type, source_id, source_url, media_id, tiporedproductotoa, NumeroSerie, SourceId, SourceUrl, SourceTitle, SourceType, direccion, nombreplanprincipal, svatotal, databeneficiosincluidos, preciopermanente, dctomensual, montomensualplan, totalproductoadicional, oct-13, variable1, nombre, mes, montopago, numboleta, fechapago, fechacorte, cargomensual, montomensual, urlarr[1], Fecha, HORA, INTERVALO, NEUTRA, Semana, Def_IBR, Llave, Flag_Outbound, MAIL, Rama, Defle_meta, fecha, access_token, activity_id, appt_number, number, img, meta_ad_id, meta_ad_headline, meta_ad_type, meta_ad_url, medios, rut_cliente, imagen, monto, numero, medio, Template, menuPrincipal, ticketCerrado, name, sept-13, marca, montofinpegado, montofin, url, ...]
# Index: []

# %% [markdown]
# # Reporte NPS

# %%
import pandas as pd
import numpy as np
import re
import unidecode
from datetime import datetime, timedelta  # Asegúrate de importar timedelta

# %%
archivo = r"C:\Users\wduran\Downloads\CSAT agente cola ticket y contacto (20).csv"
nps = pd.read_csv(archivo, delimiter=';', encoding='latin1')  # Prueba con 'latin1'

# --- 1) Eliminar la primera fila ---
nps = nps.drop(index=0).reset_index(drop=True)

# --- 2) Reemplazar con tus nombres de columnas ---
nps.columns = [
    "Ejecutivo",
    "Proveedor",
    "Cola",
    "NPS",
    "Comentario",
    "Resolutividad",
    "CSAT Asesor",
    "Comentario CSAT",
    "SUM",
    "Telefono Cliente",
    "Fecha"]

# %%
# --- 3) Convertir SUM a entero ---
nps["SUM"] = pd.to_numeric(nps["SUM"], errors="coerce")  # convierte valores no numéricos a NaN
nps["SUM"] = nps["SUM"].fillna(0).astype(int)

# %%
nps

# %%
# Eliminar todo desde la 'T' en adelante
nps['Fecha'] = nps['Fecha'].str.split('T').str[0]

# %%
nps

# %% [raw]
# # Crear la nueva columna MAIL que extrae la parte izquierda del arroba
# nps['MAIL'] = nps['Ejecutivo'].str.split('@').str[0]

# %% [raw]
# # Define the file path
# archivo = r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Dotaciones\VTR\Dotación_VTR_20250829.xlsx"
# # Read the specific sheet named 'CONSOLIDADO' from the Excel file
# dotacion = pd.read_excel(archivo, sheet_name='Dotacion')  # Specify the sheet name

# %% [raw]
# # Crear la nueva columna MAIL que extrae la parte izquierda del arroba
# dotacion['MAIL'] = dotacion['CORREO_ELECTRONICO'].str.split('@').str[0]

# %% [raw]
# # --- Merge ---
# nps = nps.merge(
#     dotacion[['MAIL', 'EMPRESA_PAIS']],   # solo las columnas necesarias
#     on='MAIL',
#     how='left'
# )

# %%
# Convertir la columna 'Fecha' a tipo datetime, manejando errores
nps['Fecha'] = pd.to_datetime(nps['Fecha'], errors='coerce')

# Comprobar si la conversión fue exitosa, y si no, encontrar las filas con errores
if nps['Fecha'].isnull().any():
    print("Algunas fechas no pudieron convertirse. Revisa los registros con errores.")

# Calcular la semana del mes (lunes a domingo)
def calcular_semana_lunes(fecha):
    if pd.isnull(fecha):
        return None
    # Primer día del mes
    primer_dia_mes = fecha.replace(day=1)  # Esta línea funciona solo si 'fecha' es tipo datetime
    # Determinar el lunes de la primera semana del mes
    primer_lunes = primer_dia_mes + timedelta(days=(7 - primer_dia_mes.weekday()) % 7)
    if primer_lunes.month != fecha.month:
        primer_lunes -= timedelta(days=7)  # Ajustar si el primer lunes cae en el mes siguiente
    # Calcular el número de semana
    delta = (fecha - primer_lunes).days
    return delta // 7 + 1 if delta >= 0 else 1

# Aplicar la función a la columna 'Fecha'
nps['Semana'] = nps['Fecha'].apply(calcular_semana_lunes)

nps.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
# Rellenar valores nulos en la columna 'Semana' con 0
nps['Semana'] = nps['Semana'].fillna(0)

# Convertir la columna 'Semana' a tipo entero
nps['Semana'] = nps['Semana'].astype(int)

# Asegurarse de que 'Semana' sea un número entero
nps['Semana'] = nps['Semana'].astype(int)

# %%
# Filtrar el DataFrame para eliminar las filas donde 'Semana' es igual a 0
nps = nps[nps['Semana'] != 0]

# %%
# Elimina duplicados basados en todas las columnas (puedes especificar columnas si lo prefieres)
nps.drop_duplicates(inplace=True)

# %%
nps

# %%
# Guardar el DataFrame como archivo CSV
nps.to_csv(r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\NPS\NPS Historiconov.csv", index=False)

# %% [markdown]
# # RED NEUTRA

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime, timedelta  # Asegúrate de importar timedelta

# %%
# Definir la ruta del archivo correctamente
archivo = r"C:\Users\wduran\Downloads\AgentHistory_soportepostventa_10-04-2025_15-05-43.csv"
neutra = pd.read_csv(archivo, delimiter=';', encoding='latin1')  # Prueba con 'latin1'

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
neutra

# %%
# Lista de valores del campo 'Team' que deseas filtrar (en minúsculas para comparación insensible a mayúsculas/minúsculas)
teams_to_filter = ['red_neutra_out']

# Filtrar la base 'blip_ha' usando .isin() para la columna 'Team'
neutra = neutra[neutra['Team'].isin(teams_to_filter)]

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
# Forzar conversión robusta a datetime, controlando zonas horarias
neutra['StorageDate'] = pd.to_datetime(neutra['StorageDate'], utc=True, errors='coerce')

# Crear el nuevo campo 'Fecha' extrayendo solo la parte de la fecha del campo 'StorageDate'
neutra['Fecha'] = pd.to_datetime(neutra['StorageDate']).dt.date

# %%
neutra.sample(20)

# %%
# Lista de campos que deseas mantener en el mismo orden
campos_necesarios = [
    'Fecha', 'ï»¿SequentialId', 'CustomerIdentity', 'AgentIdentity', 'Status',
    'StorageDate', 'CloseDate', 'QueueTime', 'FirstResponseTime', 'Team', 'Tags',
    'AverageResponseTime', 'CustomerName', 'CustomerEmail', 'CustomerGender', 
    'CustomerCity', 'CustomerPhoneNumber', 'AgentName', 'AgentEmail', 
    'tunnel.owner', 'tunnel.originator', 'campaignMessageTemplate', 'Campaign', 
    'botOrigin', 'priorityTag', 'rut', 'Menu Principal', 'Menu Hogar','team'
]

# Filtrar y reorganizar las columnas
neutra = neutra[campos_necesarios]

# %%
# Define the file path
archivo = r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Dotaciones\VTR\Dotación_VTR_20250404.xlsx"
# Read the specific sheet named 'CONSOLIDADO' from the Excel file
dotacion = pd.read_excel(archivo, sheet_name='Dotacion')  # Specify the sheet name

# %%
# Crear la nueva columna MAIL que extrae la parte izquierda del arroba
dotacion['MAIL'] = dotacion['CORREO_ELECTRONICO'].str.split('@').str[0]

# %%
# Crear la nueva columna MAIL que extrae la parte izquierda del arroba
neutra['MAIL'] = neutra['AgentIdentity'].str.split('%').str[0]

# %%
neutra = neutra.merge(dotacion[['MAIL', 'ID_ANDES',]], on='MAIL', how='left')

# %%
# Eliminar el campo 'mail'
neutra.drop(columns=['MAIL'], inplace=True)

# %%
# Elimina duplicados basados en todas las columnas (puedes especificar columnas si lo prefieres)
neutra.drop_duplicates(inplace=True)

# %%
# Quitar la zona horaria de todas las columnas datetime
for col in neutra.select_dtypes(include=['datetimetz']).columns:
    neutra[col] = neutra[col].dt.tz_localize(None)

# Ahora sí, guardás el archivo
neutra.to_excel(r"C:\Users\wduran\CLAROCHILE\Jefes de Proyecto - bases cola Neutra\Cola red neutra 2025-03.xlsx", index=False)
neutra

# %% [markdown]
# # Base FCR

# %%
import pandas as pd
import numpy as np
import re
import re, ast, unicodedata
from collections import OrderedDict

# %%
# Definir la ruta del archivo correctamente
archivo = r"C:\Users\wduran\Downloads\CSAT agente cola ticket y contacto - 2025-09-03T103319.996.csv"
blip_ha = pd.read_csv(archivo, delimiter=',', encoding='latin1')  # Prueba con 'latin1'

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
blip_ha.sample(1)

# %%
# Lista de columnas a conservar
columnas_deseadas = [
    "SequentialId", "CustomerIdentity", "AgentIdentity", 
    "Status", "Fecha", "Team", "AgentName", "AgentEmail","Tags","rut"
]

# Filtrar el DataFrame
blip_ha_FCR = blip_ha[columnas_deseadas]

# %%
# Asegurar que la columna 'Fecha' es de tipo datetime
blip_ha_FCR['Fecha'] = pd.to_datetime(blip_ha_FCR['Fecha'])

# Convertir 'team' a minúsculas, reemplazando NaN con cadena vacía
blip_ha_FCR['team_lower'] = blip_ha_FCR['Team'].astype(str).str.lower().fillna("")

# Función para calcular Flag_Konecta
def calcular_flag_konecta(row):
    if ("comercial_fijo_def" in row['team_lower'] or "tecnico_fijo_def" in row['team_lower']) and row['Fecha'] >= pd.Timestamp(2024, 11, 28):
        return 1
    elif "op_def" in row['team_lower'] and row['Fecha'] >= pd.Timestamp(2024, 12, 11):
        return 1
    elif "tecnicofinix_def" in row['team_lower'] and row['Fecha'] >= pd.Timestamp(2024, 12, 16):
        return 1
    elif "soporte_ott" in row['team_lower'] and row['Fecha'] >= pd.Timestamp(2024, 12, 19):
        return 1
    elif "op" in row['team_lower'] and row['Fecha'] >= pd.Timestamp(2024, 12, 23):
        return 1
    elif any(sub in row['team_lower'] for sub in [
        "transf desde movil", "masivos", "venta_ott", "transf desde ventas",
        "default", "transferencia directa", "consulta_boleta", "ott_max",
        "dbox smart", "ftth/iptv"
    ]) and row['Fecha'] >= pd.Timestamp(2025, 1, 15):
        return 1
    else:
        return 0

# Aplicar la función
blip_ha_FCR['Flag_Konecta'] = blip_ha_FCR.apply(calcular_flag_konecta, axis=1)

# Eliminar la columna auxiliar
blip_ha_FCR.drop(columns=['team_lower'], inplace=True)

# %%
# Define the file path
archivo = r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Dotaciones\VTR\Dotación_VTR_20250718.xlsx"
# Read the specific sheet named 'CONSOLIDADO' from the Excel file
dotacion = pd.read_excel(archivo, sheet_name='Dotacion')  # Specify the sheet name

# %%
# Crear la nueva columna MAIL que extrae la parte izquierda del arroba
dotacion['MAIL'] = dotacion['CORREO_ELECTRONICO'].str.split('@').str[0]

# %%
# Crear la nueva columna MAIL que extrae la parte izquierda del arroba
blip_ha_FCR['MAIL'] = blip_ha_FCR['AgentIdentity'].str.split('%').str[0]

# %%
blip_ha_FCR = blip_ha_FCR.merge(dotacion[['MAIL', 'ID_ANDES','EMPRESA_PAIS','PLATAFORMA','SUPERVISOR']], on='MAIL', how='left')

# %%
# Eliminar el campo 'mail'
blip_ha_FCR.drop(columns=['MAIL'], inplace=True)

# %%
blip_ha_FCR['Status'].value_counts()

# %%
blip_ha_FCRDUPLI=blip_ha_FCR

# %%
# Reducir tamaño de las columnas antes del merge
blip_ha_FCRDUPLI_reduced = blip_ha_FCRDUPLI[['CustomerIdentity', 'Fecha','Status','SequentialId','EMPRESA_PAIS']].copy()

# Realizar el join con la menor cantidad de datos posible
merged_df = blip_ha_FCR.merge(blip_ha_FCRDUPLI_reduced, on='CustomerIdentity', how='left', suffixes=('_FCR', '_FCRDUPLI'))

# Convertir a datetime para evitar errores en la resta de fechas
merged_df['Fecha_FCRDUPLI'] = pd.to_datetime(merged_df['Fecha_FCRDUPLI'])
merged_df['Fecha_FCR'] = pd.to_datetime(merged_df['Fecha_FCR'])

# Calcular la diferencia en días solo para valores no nulos
mask = merged_df['Fecha_FCRDUPLI'].notna()
merged_df.loc[mask, 'FCR'] = (merged_df.loc[mask, 'Fecha_FCRDUPLI'] - merged_df.loc[mask, 'Fecha_FCR']).dt.days

# Eliminar filas donde FCR < 1
merged_df = merged_df.loc[merged_df['FCR'] >= 1].copy()

# Filtrar solo registros donde status_fcr sea "closedattendant"
merged_df = merged_df[merged_df['Status_FCR'] == 'ClosedAttendant'].copy()

# %%
#duplicamos la base 
blip_ha_FCRDUPLI=blip_ha_FCR

# %%
merged_df.drop_duplicates(inplace=True)# Asegurar que UNICOS sea un entero
merged_df['FCR'] = merged_df['FCR'].astype(int)

# %%
equipos_claro = [
    "Cl_Tecnica_Cierre_Asegurado",
    "Cuenta Exacta Comercial",
    "Cuenta Exacta Tecnico",
    "Gestión",
    "Instalación Pendiente",
    "Postpago Comercial",
    "Postpago Tecnico",
    "trans_d_movil",
    "trans_d_ventas",
    "CE Otras Consultas",
    "Transferencia Directa",
    "Prepago Tecnico",
    "Tecnico Hogar",
    "Comercial Hogar",
    "visita_tecnica",
    "Abuse",
    "Bienvenida_OUT",
    "masivo",
    "Transferencia directa",   # (distinta capitalización)
    "Babysitting Hogar - Dia 3",
    "Babysitting Hogar - Dia 14",
    "clarobot",
]

# normalizamos a minúsculas para evitar problemas de mayúsculas/minúsculas,
# y quitamos espacios en blanco sobrantes al comienzo / final
equipos_claro_lower = [e.lower() for e in equipos_claro]

# Crea la columna MARCA
merged_df["MARCA"] = np.where(
    merged_df["Team"].str.strip().str.lower().isin(equipos_claro_lower),
    "Claro",     # cuando hay match
    "VTR"        # cuando NO hay match
)

# %%
# --- 1) Definir el diccionario (OrderedDict para respetar el orden/prioridad) ---
category_map = OrderedDict([
    ("Conectividad",       ["sin internet", "intermitencia", "velocidad", "falla de servicio",
                            "sin tono", "no recibe", "dx de servicio"]),
    ("Television_Video",   ["sin señal tv", "canal", "vod", "replay", "control remoto",
                            "dbox", "streaming", "pixeleo", "grilla"]),
    ("Facturacion_Cobros", ["factur", "boleta", "cobro", "repo", "deuda", "saldo",
                            "descuento", "ajuste", "promo no aplicado"]),
    ("Pagos_Prorroga",     ["pago no aplicado", "pat-pac", "prorroga", "inhibicion",
                            "opcion de pago", "consulta saldo"]),
    ("Instalacion_Visita", ["visita", "instalaci", "autoinstal", "delivery", "entrega",
                            "traslado", "escalado", "mesa de ayuda"]),
    ("Plan_Promocion",     ["cambio de plan", "oferta", "cotiz", "actuali", "promo",
                            "venta", "cambio de ciclo", "modificaciones contrato",
                            "cambio de titular"]),
    ("Portabilidad_Equipo",["portabilidad", "cambio de equipo", "agregar servicio"]),
    ("SVA_Premium",        ["sva", "canal premium", "baja de sva"]),
    ("Digital_App",        ["sucursal virtual", "app", "videollamada", "boton rojo",
                            "1_streaming", "2_streaming", "trans_"]),
    ("Otros",              [])  # catch‑all
])

# --- 2) Función utilitaria para normalizar texto (quitar tildes y pasar a minúsculas) ---
def _normalize(text):
    if not isinstance(text, str):
        return ""
    text = unicodedata.normalize("NFKD", text).encode("ascii", "ignore").decode("ascii")
    return text.lower()

# --- 3) Función que asigna la categoría a un registro ---
def categorize_tags(tag_cell):
    """
    tag_cell puede ser:
      • una lista real (['Sin internet', 'Sin señal TV'])
      • una string tipo "['Sin internet', 'Sin señal TV']"
      • una string simple ('Sin internet')
    """
    # Convertir a lista de strings
    if isinstance(tag_cell, list):
        tags = tag_cell
    else:
        try:
            tags = ast.literal_eval(tag_cell)  # intenta interpretar como lista en texto
            if not isinstance(tags, list):
                tags = [tag_cell]
        except Exception:
            tags = [tag_cell]

    # Normalizar y buscar
    norm_tags = [_normalize(t) for t in tags]

    for cat, keywords in category_map.items():
        if not keywords:          # "Otros"
            continue
        for kw in keywords:
            if any(kw in t for t in norm_tags):
                return cat
    return "Otros"

# --- 4) Aplicar a tu DataFrame ---
merged_df["Motivo_FCR"] = merged_df["Tags"].apply(categorize_tags)

# %%
merged_df.sample(1)

# %%
merged_df = merged_df[merged_df['MARCA'] == 'VTR']

# %%
# Guardar el DataFrame como archivo CSV
merged_df.to_excel(r"C:\Users\wduran\Downloads\FCR MOTIVOS.xlsx", index=False)

# %% [markdown]
# # CLIENTES NUEVOS

# %%
# Seleccionar solo las columnas necesarias
blip_ha_seleccionada = blip_ha[['tunnel.originator', 'StorageDate']]

# %%
# Crear el nuevo campo 'Fecha' extrayendo solo la parte de la fecha del campo 'StorageDate'
blip_ha_seleccionada['Fecha'] = pd.to_datetime(blip_ha_seleccionada['StorageDate']).dt.date

# %%
# Eliminar la columna 'StorageDate'
blip_ha_seleccionada = blip_ha_seleccionada.drop(columns=['StorageDate'])

# %%
# Convertir la columna 'Fecha' a tipo datetime
blip_ha_seleccionada['Fecha'] = pd.to_datetime(blip_ha_seleccionada['Fecha'])

# Filtrar los registros con la fecha más antigua para cada 'tunnel.originator'
blip_ha_ordenada = blip_ha_seleccionada.sort_values('Fecha')  # Ordenar por fecha de menor a mayor
blip_ha_filtrada = blip_ha_ordenada.drop_duplicates(subset='tunnel.originator', keep='first')  # Mantener solo el primer registro

# %%
blip_ha_filtrada

# %%
# Guardar el DataFrame como archivo CSV
blip_ha_filtrada.to_csv(r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Blip Historial de Atenciones\CHATS 2025\Clientes_Nuevos.csv", index=False)

# %% [markdown]
# # PEDIDA NATI

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime, timedelta  # Asegúrate de importar timedelta

# %%
# Definir la ruta del archivo correctamente
archivo = r"C:\Users\wduran\Downloads\202506_StockFijo_VTR.csv"
stock = pd.read_csv(archivo, delimiter=';', encoding='latin1')  # Prueba con 'latin1'

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
stock.sample(1)

# %%
f_blip_ha_merge.sample(1)

# %%
# Suponiendo que ya tienes cargada la base f_blip_ha_merge
# Paso 1: Seleccionar solo las columnas deseadas
f_blip_filtrada = f_blip_ha_merge[['Fecha', 'INTERVALO', 'rut']]

# Paso 2: Filtrar por fechas específicas
fechas_deseadas = ['2025-06-11', '2025-06-12']
f_blip_filtrada = f_blip_filtrada[f_blip_filtrada['Fecha'].isin(fechas_deseadas)]

# %%
f_blip_filtrada.sample(6)

# %%
# Paso 1: Hacer el join (left join para mantener todas las filas de f_blip_filtrada)
f_blip_enriquecida = f_blip_filtrada.merge(
    stock[['ID_CLIENTE', 'REGION', 'COMUNA', 'X_OCS_TIPO_RED_PROD']],
    left_on='rut',
    right_on='ID_CLIENTE',
    how='left'
)

# Paso 2: Eliminar la columna auxiliar 'ID_CLIENTE' si no la necesitas
f_blip_enriquecida.drop(columns=['ID_CLIENTE'], inplace=True)

# %%
f_blip_enriquecida

# %%
# Guardar el DataFrame como archivo CSV
f_blip_enriquecida.to_csv(r"C:\Users\wduran\Downloads\natipedidaciada.csv", index=False)

# %% [markdown]
# # arreglar BLIP HISTIORIAL

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime, timedelta  # Asegúrate de importar timedelta

# %%
# Definir la ruta del archivo correctamente
archivo = r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Blip Power Bi Base\f_blip_ha- Consolidado.csv"
f_blip_ha = pd.read_csv(archivo, delimiter=',', encoding='latin1')  # Prueba con 'latin1'

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
f_blip_ha

# %%
# Eliminar duplicados por SequentialId y conservar el primero
f_blip_ha = f_blip_ha.drop_duplicates(subset='SequentialId', keep='first')

# %%
f_blip_ha

# %%
# 5️⃣ Filtrar desde mayo 2025 en adelante
df_consolidado_filtrado = f_blip_ha[f_blip_ha['Fecha'] >= '2025-05-01']

# %%
df_consolidado_filtrado

# %%
# Guardar el DataFrame como archivo CSV
df_consolidado_filtrado.to_csv(r"C:\Users\wduran\OneDrive - CLAROCHILE\Digital Team\Blip Power Bi Base\f_blip_ha.csv", index=False)

# %% [markdown]
# # TRACKEAR MASIVOS DEL 26 AL 02

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime, timedelta  # Asegúrate de importar timedelta

# %%
# Definir la ruta del archivo correctamente
archivo = r"C:\Users\wduran\Downloads\Recorrido_VTR_26.csv"
recorrido = pd.read_csv(archivo, delimiter=';', encoding='latin1')  # Prueba con 'latin1'

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
# Definir la ruta del archivo correctamente
archivo = r"C:\Users\wduran\Downloads\BASE N0 19-02  1.csv"
llamadas = pd.read_csv(archivo, delimiter=';', encoding='latin1')  # Prueba con 'latin1'

# Ajustar las opciones para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
llamadas.sample(1)

# %%
llamadas["ID CLIENTE"] = llamadas["ID CLIENTE"].astype(str).str.lstrip("0")

# %%
llamadas["LLAVE"] = llamadas["ID CLIENTE"].astype(str) + "_" + llamadas["FECHA"].astype(str)

# %%
recorrido["LLAVE"] = recorrido["ID_CLIENTE"].astype(str) + "_" + recorrido["FECHA_GESTION"].astype(str)

# %%
recorrido["ID_CLIENTE"] = recorrido["ID_CLIENTE"].astype(str).str.strip().str.lstrip("0")
llamadas["RUT_CLIENTE"] = llamadas["RUT_CLIENTE"].astype(str).str.strip().str.lstrip("0")

# %%
recorrido = recorrido.merge(
    llamadas[["ID CLIENTE", "CIUDAD"]],
    left_on="ID_CLIENTE",
    right_on="ID CLIENTE",
    how="left"
)

# %%
recorrido["FLAG_LLAMADA"] = recorrido["CIUDAD"].notna().astype(int)

# %%
recorrido

# %%
ruta_salida = r"C:\Users\wduran\Downloads\Base Recorrido y llamadas del 19 al 25.xlsx"

recorrido.to_excel(ruta_salida, index=False)
