# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
import pandas as pd
import gzip


file_path = r"\\10.33.3.112\reportes_gestion\cartera_postpago\cartera\CARTERA_POSTPAGO_202407_202407.txt.gz"


with gzip.open(file_path, 'rt') as f:

    df = pd.read_csv(f, delimiter='|', encoding = 'latin-1')

df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_65224/2884943692.py in <module>
#       8 with gzip.open(file_path, 'rt') as f:
#       9
# ---> 10     df = pd.read_csv(f, delimiter='|', encoding = 'latin-1')
#      11
#      12 df.sample(5)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv(r"C:\Users\ctorof\CLAROCHILE\Revenue Management, CBM y Calidad de Venta - Documentos\CBM\FIJO\STOCKS\VTR\TABLAE\202407_StockTotal.csv")
# Out:
# C:\Users\ctorof\AppData\Local\Temp/ipykernel_65224/2707848994.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\ctorof\CLAROCHILE\Revenue Management, CBM y Calidad de Venta - Documentos\CBM\FIJO\STOCKS\VTR\TABLAE\202407_StockTotal.csv")

# %%
df.loc[df.ID_CLIENTE == '12389687-4']
# Out:
#         ID_MES_ANALISIS  ID_CLIENTE  ID_VIVIENDA_GIS        RUT_VIVIENDA  \
# 146750           202407  12389687-4       20798092.0  12389687-420798092
#
#          NOMBRE_CTA_SERV NOMBRE_CTA_FACT           PROMO  ID_PROMO  \
# 146750  12389687-4-S-001    217624140348  VTR Wifi 0822F  1-1352JB
#
#        NIVEL_EMPAQUETADO X_OCS_TIPO_RED ID_PROD_INTERNET          INTERNET  \
# 146750            1 Play           FTTH         1-10KSYE  500M Residencial
#
#         RENTA_INTERNET ID_PROD_CABLE PRODUCTO_CABLE  RENTA_CABLE ID_PROD_FONO  \
# 146750          2185.0           NaN            NaN          NaN          NaN
#
#        PRODUCTO_FONO  RENTA_FONO  RENTA_TOTAL  VALOR_DESC_MULTISERVICIO  \
# 146750           NaN         NaN         2185                         0
#
#         VALOR_DESC_PERMANENTE  VALOR_DESC_UPSELLING  VALOR_DESC_RETENCION  \
# 146750                      0                     0                 -6000
#
# ...

# %%
df.loc[df.ID_CLIENTE == '11411236-4']
# Out:
#        ID_MES_ANALISIS  ID_CLIENTE  ID_VIVIENDA_GIS        RUT_VIVIENDA  \
# 74789           202407  11411236-4       20791874.0  11411236-420791874
#
#         NOMBRE_CTA_SERV NOMBRE_CTA_FACT  \
# 74789  11411236-4-S-001    236607530477
#
#                                           PROMO  ID_PROMO NIVEL_EMPAQUETADO  \
# 74789  3P 600 Megas mas Stream TV Premium 0324F  1-149P8N            3 Play
#
#       X_OCS_TIPO_RED ID_PROD_INTERNET          INTERNET  RENTA_INTERNET  \
# 74789           FTTH         1-10KSYJ  600M Residencial         21990.0
#
#       ID_PROD_CABLE     PRODUCTO_CABLE  RENTA_CABLE ID_PROD_FONO  \
# 74789      1-145WPD  Stream TV Premium      28990.0      1-DNZHD
#
#                   PRODUCTO_FONO  RENTA_FONO  RENTA_TOTAL  \
# 74789  Fono Ilimitado 600 Movil     12990.0        63970
#
#        VALOR_DESC_MULTISERVICIO  VALOR_DESC_PERMANENTE  VALOR_DESC_UPSELLING  \
# 74789                    -11980                      0                     0
#
# ...

# %%
ret = pd.read_csv(r"C:\Users\ctorof\CLAROCHILE\Nicoll Constanza Aguirre Diaz - dcabello\Dashboards Nueva Oferta\INPUTS\INPUTS JAVIER\Retencion\Activos\20240630 Descuentos Retención Activos.csv", delimiter = ';')

# %%
ret.loc[ret.id_cliente== '11411236-4']
# Out:
#              FECH_ALTA  ANOMES_ALTA  id_cliente   RUT_PERSONA  IDEN_VIVIENDA  \
# 9839   27-06-2024 0:00       202406  11411236-4  0011411236-4       20791874
# 58936  27-06-2024 0:00       202406  11411236-4  0011411236-4       20791874
# 84686  27-06-2024 0:00       202406  11411236-4  0011411236-4       20791874
#
#                             NOMBRE_PRODUCTO  MONTO_DSCTO FECHA_FIN_DESCUENTOS  \
# 9839   Descuento Retencion 16.000 x 6 Meses       -16000      21-01-2025 0:00
# 58936  Descuento Retencion 13.000 x 6 Meses       -13000      21-01-2025 0:00
# 84686  Descuento Retencion 11.000 x 6 Meses       -11000      21-01-2025 0:00
#
#       ESTADO_ACTIVO NOMBRE_CUENTA_FACTURACION TIPO_CLIENTE
# 9839         Activo               2,36608E+11  Residencial
# 58936        Activo               2,36608E+11  Residencial
# 84686        Activo               2,36608E+11  Residencial
